# %%
## Importing the necessary libraries
import re
import numpy as np
from tqdm import tqdm
import warnings

# %%
# loading the data
inp_data ="Since the so-called statistical revolution in the late 1980s and mid-1990s, much natural language processing research has relied heavily on machine learning. The machine-learning paradigm calls instead for using statistical inference to automatically learn such rules through the analysis of large corpora (the plural form of corpus, is a set of documents, possibly with human or computer annotations) of typical real-world examples.Many different classes of machine-learning algorithms have been applied to natural-language-processing tasks. These algorithms take as input a large set of features that are generated from the input data. Increasingly, however, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to each input feature (complex-valued embeddings,[17] and neural networks in general have also been proposed, for e.g. speech[18]). Such models have the advantage that they can express the relative certainty of many different possible answers rather than only one, producing more reliable results when such a model is included as a component of a larger system.Some of the earliest-used machine learning algorithms, such as decision trees, produced systems of hard if-then rules similar to existing hand-written rules. However, part-of-speech tagging introduced the use of hidden Markov models to natural language processing, and increasingly, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to the features making up the input data. The cache language models upon which many speech recognition systems now rely are examples of such statistical models. Such models are generally more robust when given unfamiliar input, especially input that contains errors (as is very common for real-world data), and produce more reliable results when integrated into a larger system comprising multiple subtasks.Since the neural turn, statistical methods in NLP research have been largely replaced by neural networks. However, they continue to be relevant for contexts in which statistical interpretability and transparency is required.A major drawback of statistical methods is that they require elaborate feature engineering. Since 2015,[19] the field has thus largely abandoned statistical methods and shifted to neural networks for machine learning. Popular techniques include the use of word embeddings to capture semantic properties of words, and an increase in end-to-end learning of a higher-level task (e.g., question answering) instead of relying on a pipeline of separate intermediate tasks (e.g., part-of-speech tagging and dependency parsing). In some areas, this shift has entailed substantial changes in how NLP systems are designed, such that deep neural network-based approaches may be viewed as a new paradigm distinct from statistical natural language processing. For instance, the term neural machine translation (NMT) emphasizes the fact that deep learning-based approaches to machine translation directly learn sequence-to-sequence transformations, obviating the need for intermediate steps such as word alignment and language modeling that was used in statistical machine translation (SMT)."

# %%
# remove special characters
inp_data2 = re.sub('[^A-Za-z0-9]+', ' ', inp_data)

# remove 1 letter words
inp_data2 = re.sub(r'(?:^| )\w(?:$| )', ' ', inp_data2).strip()

# lower all characters
inp_data2 = inp_data2.lower()

# %%
inp_data2
# Out:
# 'since the so called statistical revolution in the late 1980s and mid 1990s much natural language processing research has relied heavily on machine learning the machine learning paradigm calls instead for using statistical inference to automatically learn such rules through the analysis of large corpora the plural form of corpus is set of documents possibly with human or computer annotations of typical real world examples many different classes of machine learning algorithms have been applied to natural language processing tasks these algorithms take as input large set of features that are generated from the input data increasingly however research has focused on statistical models which make soft probabilistic decisions based on attaching real valued weights to each input feature complex valued embeddings 17 and neural networks in general have also been proposed for g speech 18 such models have the advantage that they can express the relative certainty of many different possible answers rather than only one producing more reliable results when such model is included as component of larger system some of the earliest used machine learning algorithms such as decision trees produced systems of hard if then rules similar to existing hand written rules however part of speech tagging introduced the use of hidden markov models to natural language processing and increasingly research has focused on statistical models which make soft probabilistic decisions based on attaching real valued weights to the features making up the input data the cache language models upon which many speech recognition systems now rely are examples of such statistical models such models are generally more robust when given unfamiliar input especially input that contains errors as is very common for real world data and produce more reliable results when integrated into larger system comprising multiple subtasks since the neural turn statistical methods in nlp research have been largely replaced by neural networks however they continue to be relevant for contexts in which statistical interpretability and transparency is required major drawback of statistical methods is that they require elaborate feature engineering since 2015 19 the field has thus largely abandoned statistical methods and shifted to neural networks for machine learning popular techniques include the use of word embeddings to capture semantic properties of words and an increase in end to end learning of higher level task g question answering instead of relying on pipeline of separate intermediate tasks g part of speech tagging and dependency parsing in some areas this shift has entailed substantial changes in how nlp systems are designed such that deep neural network based approaches may be viewed as new paradigm distinct from statistical natural language processing for instance the term neural machine translation nmt emphasizes the fact that deep learning based approaches to machine translation directly learn sequence to sequence transformations obviating the need for intermediate steps such as word alignment and language modeling that was used in statistical machine translation smt'

# %%
tokens = inp_data2.split()
vocab = set(tokens)

# %%
word_to_index = {word: i for i, word in enumerate(vocab)}
index_to_word = {i: word for i, word in enumerate(vocab)}

# %%
context_size = 4 #Hyper-parameter
batch_size = 8
embedding_size = 10 #Hyper-parameter
vocab_size = len(vocab) #Number of unique tokens in the vocabulary

# %%
embedding_size, vocab_size
# Out:
# (10, 240)

# %%
data = []

for i in range(context_size, len(tokens) - context_size):
  target = tokens[i]
  context = []
  for j in range(1, context_size+1):
    context += [tokens[i-j], tokens[i+j]]  
  data.append((context, target))

print(data[:5])
# Out:
# [(['called', 'revolution', 'so', 'in', 'the', 'the', 'since', 'late'], 'statistical'), (['statistical', 'in', 'called', 'the', 'so', 'late', 'the', '1980s'], 'revolution'), (['revolution', 'the', 'statistical', 'late', 'called', '1980s', 'so', 'and'], 'in'), (['in', 'late', 'revolution', '1980s', 'statistical', 'and', 'called', 'mid'], 'the'), (['the', '1980s', 'in', 'and', 'revolution', 'mid', 'statistical', '1990s'], 'late')]

# %%
len(data)
# Out:
# 474

# %%
# Initialize Weights and Bias matrices
def initialize_weights(vocab_size, embedding_size):
  W1 = np.random.rand(embedding_size, vocab_size)
  W2 = np.random.rand(vocab_size, embedding_size)
  b1 = np.random.rand(embedding_size, 1)
  b2 = np.random.rand(vocab_size, 1)
  return W1, b1, W2, b2

# %%
def softmax_activation(z):
  return np.exp(z)/np.sum(np.exp(z), axis=0)

# %%
# Forward Propagation:
# 1. Linear Hidden State: h = W1.x + b1
# 2. Output Layer:        z = W2.h + b2
# 3. Softmax Activation:  z = softmax_activation(z)

def forward_propagation(X, W1, W2, b1, b2):
  # Compute Hidden Layer values
  h = np.dot(W1, X) + b1
  # Compute Output Layer Values
  z = np.dot(W2, h) + b2
  return z, h

# %%
def transform_data(context_words, target_word, vocab_size):
  input_vector = np.zeros((vocab_size, 1))
  target_vector = np.zeros((vocab_size, 1))
  
  for word in context_words:
    input_vector[word_to_index[word]] += 1
  
  input_vector = input_vector/len(context_words)

  target_vector[word_to_index[target_word]]=1

  return input_vector.reshape(1, -1), target_vector.reshape(1, -1)

# %%
def transform_batch_data(batch_data, vocab_size):
  X=np.zeros((vocab_size, len(batch_data)))
  y=np.zeros((vocab_size, len(batch_data)))

  for i in range(len(batch_data)):
    context_words = batch_data[i][0]
    target_word = batch_data[i][1]

    X[:, i], y[:, i] = transform_data(context_words, target_word, vocab_size)

  return X, y

# %%
def get_batch_indices(data, batch_size):
  batch_indices = []

  for i in range(0, len(data), batch_size):
    if (i+batch_size <= len(data)):
      batch_indices.append((i, i+batch_size))
    else:
      batch_indices.append((i, len(data)))
  return batch_indices

# %%
batch_indices = get_batch_indices(data, batch_size)

batch_indices
# Out:
# [(0, 8),
#  (8, 16),
#  (16, 24),
#  (24, 32),
#  (32, 40),
#  (40, 48),
#  (48, 56),
#  (56, 64),
#  (64, 72),
#  (72, 80),
#  (80, 88),
#  (88, 96),
#  (96, 104),
#  (104, 112),
#  (112, 120),
#  (120, 128),
#  (128, 136),
#  (136, 144),
#  (144, 152),
#  (152, 160),
#  (160, 168),
#  (168, 176),
#  (176, 184),
#  (184, 192),
#  (192, 200),
#  (200, 208),
#  (208, 216),
#  (216, 224),
#  (224, 232),
#  (232, 240),
#  (240, 248),
#  (248, 256),
#  (256, 264),
#  (264, 272),
#  (272, 280),
#  (280, 288),
#  (288, 296),
#  (296, 304),
#  (304, 312),
#  (312, 320),
#  (320, 328),
#  (328, 336),
#  (336, 344),
#  (344, 352),
#  (352, 360),
#  (360, 368),
#  (368, 376),
#  (376, 384),
#  (384, 392),
#  (392, 400),
#  (400, 408),
#  (408, 416),
#  (416, 424),
#  (424, 432),
#  (432, 440),
#  (440, 448),
#  (448, 456),
#  (456, 464),
#  (464, 472),
#  (472, 474)]

# %%
# compute_cost: cross-entropy cost functioN
def compute_cost(y, yhat, batch_size):
    # cost function 
    logprobs = np.multiply(np.log(yhat),y)
    cost = - 1/batch_size * np.sum(logprobs)
    cost = np.squeeze(cost)
    return cost

# %%
def back_propagation(X, y_hat, y, h, W1, W2, b1, b2, batch_size):
    
    l1 = np.dot(W2.T,(y_hat-y))
    
    grad_W1 = (1/batch_size)*np.dot(l1, X.T) 
    
    grad_W2 = (1/batch_size)*np.dot(y_hat-y, h.T)
    
    grad_b1 = np.sum((1/batch_size)*np.dot(l1, X.T), axis=1, keepdims=True)
    
    grad_b2 = np.sum((1/batch_size)*np.dot(y_hat-y,h.T), axis=1, keepdims=True)
    
    return grad_W1, grad_W2, grad_b1, grad_b2

# %%
alpha = 0.3

W1, b1, W2, b2 = initialize_weights(vocab_size, embedding_size)

batch_indices = get_batch_indices(data, batch_size)

for i in range(1000):
  for start_index, end_index in batch_indices:
    X, y = transform_batch_data(data[start_index:end_index], vocab_size)
    z, h = forward_propagation(X, W1, W2, b1, b2)
    y_hat = softmax_activation(z)
    cost = compute_cost(y, y_hat, batch_size)

    grad_W1, grad_W2, grad_b1, grad_b2 = back_propagation(X, y_hat, y, h, W1, W2, b1, b2, batch_size)
          
    # Update weights and biases
    W1 -= alpha*grad_W1 
    W2 -= alpha*grad_W2
    b1 -= alpha*grad_b1
    b2 -= alpha*grad_b2
  print("Cost: ", cost, " after Iteration#: ", i+1)
# Out:
# Cost:  1.2878601616429628  after Iteration#:  1
# Cost:  1.234898664077562  after Iteration#:  2
# Cost:  1.2153580496212562  after Iteration#:  3
# Cost:  1.202254803795497  after Iteration#:  4
# Cost:  1.1917181761320295  after Iteration#:  5
# Cost:  1.1824915180731335  after Iteration#:  6
# Cost:  1.1739756548293971  after Iteration#:  7
# Cost:  1.1658323459834787  after Iteration#:  8
# Cost:  1.1578551403684743  after Iteration#:  9
# Cost:  1.1499133562189974  after Iteration#:  10
# Cost:  1.1419233656181884  after Iteration#:  11
# Cost:  1.1338323069040515  after Iteration#:  12
# Cost:  1.1256081972911172  after Iteration#:  13
# Cost:  1.117233617659576  after Iteration#:  14
# Cost:  1.1087015124913335  after Iteration#:  15
# Cost:  1.1000123104786466  after Iteration#:  16
# Cost:  1.0911719206480515  after Iteration#:  17
# Cost:  1.0821903555166823  after Iteration#:  18
# Cost:  1.0730808489343002  after Iteration#:  19
# Cost:  1.063859406326971  after Iteration#:  20
# Cost:  1.0545447659991076  after Iteration#:  21
# Cost:  1.0451587703450906  after Iteration#:  22
# Cost:  1.035727149467788  after Iteration#:  23
# Cost:  1.0262807091179198  after Iteration#:  24
# Cost:  1.0168568916258858  after Iteration#:  25
# Cost:  1.007501643910322  after Iteration#:  26
# Cost:  0.9982714825357566  after Iteration#:  27
# Cost:  0.9892355980744105  after Iteration#:  28
# Cost:  0.9804778136665344  after Iteration#:  29
# Cost:  0.9720982946310908  after Iteration#:  30
# Cost:  0.9642154005473655  after Iteration#:  31
# Cost:  0.9569699505743201  after Iteration#:  32
# Cost:  0.950540264815369  after Iteration#:  33
# Cost:  0.9451920193379018  after Iteration#:  34
# Cost:  0.9413889704132293  after Iteration#:  35
# Cost:  0.9395774668778454  after Iteration#:  36
# Cost:  0.9369229601626549  after Iteration#:  37
# Cost:  0.9233309739112607  after Iteration#:  38
# Cost:  0.9003839095896546  after Iteration#:  39
# Cost:  0.8876369767206407  after Iteration#:  40
# Cost:  0.8781126407951998  after Iteration#:  41
# Cost:  0.86680373073597  after Iteration#:  42
# Cost:  0.8543869908186174  after Iteration#:  43
# Cost:  0.8412347920409657  after Iteration#:  44
# Cost:  0.8275672021998197  after Iteration#:  45
# Cost:  0.8135678763222001  after Iteration#:  46
# Cost:  0.799412694517998  after Iteration#:  47
# Cost:  0.7852664943371848  after Iteration#:  48
# Cost:  0.7712754816453659  after Iteration#:  49
# Cost:  0.757565265023941  after Iteration#:  50
# Cost:  0.7442412832535744  after Iteration#:  51
# Cost:  0.7313883574220812  after Iteration#:  52
# Cost:  0.719069862856779  after Iteration#:  53
# Cost:  0.7073281295188416  after Iteration#:  54
# Cost:  0.6961866579186345  after Iteration#:  55
# Cost:  0.685653582468117  after Iteration#:  56
# Cost:  0.6757254267774119  after Iteration#:  57
# Cost:  0.6663904183128799  after Iteration#:  58
# Cost:  0.6576310151390337  after Iteration#:  59
# Cost:  0.6494255877241072  after Iteration#:  60
# Cost:  0.6417493623758023  after Iteration#:  61
# Cost:  0.6345748231979058  after Iteration#:  62
# Cost:  0.6278718204616008  after Iteration#:  63
# Cost:  0.6216076391907942  after Iteration#:  64
# Cost:  0.6157472277674613  after Iteration#:  65
# Cost:  0.6102536814810661  after Iteration#:  66
# Cost:  0.6050889571992051  after Iteration#:  67
# Cost:  0.6002147057908592  after Iteration#:  68
# Cost:  0.5955930736627607  after Iteration#:  69
# Cost:  0.5911873430329655  after Iteration#:  70
# Cost:  0.5869623336413535  after Iteration#:  71
# Cost:  0.5828845526109055  after Iteration#:  72
# Cost:  0.5789221345861414  after Iteration#:  73
# Cost:  0.575044649797514  after Iteration#:  74
# Cost:  0.571222870134448  after Iteration#:  75
# Cost:  0.5674285754644585  after Iteration#:  76
# Cost:  0.5636344605809894  after Iteration#:  77
# Cost:  0.5598141747083293  after Iteration#:  78
# Cost:  0.5559424971928045  after Iteration#:  79
# Cost:  0.5519956298298391  after Iteration#:  80
# Cost:  0.5479515709391607  after Iteration#:  81
# Cost:  0.5437905294054015  after Iteration#:  82
# Cost:  0.5394953374042585  after Iteration#:  83
# Cost:  0.5350518263612867  after Iteration#:  84
# Cost:  0.5304491393379123  after Iteration#:  85
# Cost:  0.5256799620959157  after Iteration#:  86
# Cost:  0.5207406626611721  after Iteration#:  87
# Cost:  0.515631334211888  after Iteration#:  88
# Cost:  0.5103557384334426  after Iteration#:  89
# Cost:  0.5049211468765592  after Iteration#:  90
# Cost:  0.49933807770541516  after Iteration#:  91
# Cost:  0.4936199260934542  after Iteration#:  92
# Cost:  0.4877824897026346  after Iteration#:  93
# Cost:  0.48184339677700494  after Iteration#:  94
# Cost:  0.4758214531049316  after Iteration#:  95
# Cost:  0.46973593426667215  after Iteration#:  96
# Cost:  0.46360585931947973  after Iteration#:  97
# Cost:  0.45744928924148315  after Iteration#:  98
# Cost:  0.45128269614321675  after Iteration#:  99
# Cost:  0.44512044625474584  after Iteration#:  100
# Cost:  0.4389744308568428  after Iteration#:  101
# Cost:  0.43285386566798045  after Iteration#:  102
# Cost:  0.42676526274653487  after Iteration#:  103
# Cost:  0.42071256231218657  after Iteration#:  104
# Cost:  0.41469739761856717  after Iteration#:  105
# Cost:  0.408719456136997  after Iteration#:  106
# Cost:  0.40277689589396887  after Iteration#:  107
# Cost:  0.3968667768157752  after Iteration#:  108
# Cost:  0.3909854724173047  after Iteration#:  109
# Cost:  0.38512903559073625  after Iteration#:  110
# Cost:  0.3792935018952265  after Iteration#:  111
# Cost:  0.3734751230986766  after Iteration#:  112
# Cost:  0.3676705316695236  after Iteration#:  113
# Cost:  0.36187684284638594  after Iteration#:  114
# Cost:  0.3560917046641808  after Iteration#:  115
# Cost:  0.35031330806199074  after Iteration#:  116
# Cost:  0.34454036931517035  after Iteration#:  117
# Cost:  0.338772095973157  after Iteration#:  118
# Cost:  0.33300814568390746  after Iteration#:  119
# Cost:  0.3272485851197956  after Iteration#:  120
# Cost:  0.32149385397803043  after Iteration#:  121
# Cost:  0.31574473691813226  after Iteration#:  122
# Cost:  0.3100023444561577  after Iteration#:  123
# Cost:  0.3042681023416389  after Iteration#:  124
# Cost:  0.2985437478375394  after Iteration#:  125
# Cost:  0.29283133061206806  after Iteration#:  126
# Cost:  0.28713321561268085  after Iteration#:  127
# Cost:  0.2814520852832841  after Iteration#:  128
# Cost:  0.27579093874375105  after Iteration#:  129
# Cost:  0.2701530860031808  after Iteration#:  130
# Cost:  0.2645421358474079  after Iteration#:  131
# Cost:  0.25896197665362236  after Iteration#:  132
# Cost:  0.2534167499773914  after Iteration#:  133
# Cost:  0.24791081728174336  after Iteration#:  134
# Cost:  0.2424487206029101  after Iteration#:  135
# Cost:  0.23703513825746847  after Iteration#:  136
# Cost:  0.23167483688919308  after Iteration#:  137
# Cost:  0.2263726212393557  after Iteration#:  138
# Cost:  0.22113328301662927  after Iteration#:  139
# Cost:  0.21596155016086732  after Iteration#:  140
# Cost:  0.2108620376590298  after Iteration#:  141
# Cost:  0.20583920090086674  after Iteration#:  142
# Cost:  0.2008972923747842  after Iteration#:  143
# Cost:  0.1960403223160021  after Iteration#:  144
# Cost:  0.19127202374233132  after Iteration#:  145
# Cost:  0.18659582215672144  after Iteration#:  146
# Cost:  0.18201481006582135  after Iteration#:  147
# Cost:  0.17753172636213937  after Iteration#:  148
# Cost:  0.17314894054270114  after Iteration#:  149
# Cost:  0.16886844168538306  after Iteration#:  150
# Cost:  0.16469183206922425  after Iteration#:  151
# Cost:  0.1606203253001641  after Iteration#:  152
# Cost:  0.15665474878164848  after Iteration#:  153
# Cost:  0.15279555034475825  after Iteration#:  154
# Cost:  0.14904280882072682  after Iteration#:  155
# Cost:  0.14539624829837355  after Iteration#:  156
# Cost:  0.1418552557606356  after Iteration#:  157
# Cost:  0.1384189017410754  after Iteration#:  158
# Cost:  0.1350859635871529  after Iteration#:  159
# Cost:  0.13185495086755433  after Iteration#:  160
# Cost:  0.12872413242092604  after Iteration#:  161
# Cost:  0.12569156451737717  after Iteration#:  162
# Cost:  0.1227551195949266  after Iteration#:  163
# Cost:  0.11991251504205516  after Iteration#:  164
# Cost:  0.11716134152411771  after Iteration#:  165
# Cost:  0.11449909039377304  after Iteration#:  166
# Cost:  0.11192317978068496  after Iteration#:  167
# Cost:  0.10943097901995254  after Iteration#:  168
# Cost:  0.10701983114813268  after Iteration#:  169
# Cost:  0.10468707326682841  after Iteration#:  170
# Cost:  0.10243005464343649  after Iteration#:  171
# Cost:  0.10024615248447241  after Iteration#:  172
# Cost:  0.09813278537707731  after Iteration#:  173
# Cost:  0.09608742444786109  after Iteration#:  174
# Cost:  0.09410760233443076  after Iteration#:  175
# Cost:  0.09219092010357319  after Iteration#:  176
# Cost:  0.09033505228103485  after Iteration#:  177
# Cost:  0.08853775018120795  after Iteration#:  178
# Cost:  0.08679684374094707  after Iteration#:  179
# Cost:  0.08511024207041816  after Iteration#:  180
# Cost:  0.08347593293562598  after Iteration#:  181
# Cost:  0.08189198138253818  after Iteration#:  182
# Cost:  0.08035652770220963  after Iteration#:  183
# Cost:  0.07886778492075248  after Iteration#:  184
# Cost:  0.07742403597854906  after Iteration#:  185
# Cost:  0.07602363074076765  after Iteration#:  186
# Cost:  0.07466498295738623  after Iteration#:  187
# Cost:  0.07334656726664782  after Iteration#:  188
# Cost:  0.0720669163123603  after Iteration#:  189
# Cost:  0.07082461802364154  after Iteration#:  190
# Cost:  0.06961831308629139  after Iteration#:  191
# Cost:  0.068446692618504  after Iteration#:  192
# Cost:  0.06730849605028803  after Iteration#:  193
# Cost:  0.06620250919578284  after Iteration#:  194
# Cost:  0.06512756250047345  after Iteration#:  195
# Cost:  0.06408252944078047  after Iteration#:  196
# Cost:  0.06306632505126446  after Iteration#:  197
# Cost:  0.062077904554252744  after Iteration#:  198
# Cost:  0.06111626206772183  after Iteration#:  199
# Cost:  0.06018042936925229  after Iteration#:  200
# Cost:  0.059269474696571726  after Iteration#:  201
# Cost:  0.0583825015682904  after Iteration#:  202
# Cost:  0.0575186476117589  after Iteration#:  203
# Cost:  0.0566770833883574  after Iteration#:  204
# Cost:  0.05585701120991434  after Iteration#:  205
# Cost:  0.05505766394331962  after Iteration#:  206
# Cost:  0.05427830380362036  after Iteration#:  207
# Cost:  0.0535182211390619  after Iteration#:  208
# Cost:  0.05277673321450602  after Iteration#:  209
# Cost:  0.052053183002390445  after Iteration#:  210
# Cost:  0.05134693799278964  after Iteration#:  211
# Cost:  0.050657389036003225  after Iteration#:  212
# Cost:  0.049983949232326234  after Iteration#:  213
# Cost:  0.049326052884019936  after Iteration#:  214
# Cost:  0.04868315452391414  after Iteration#:  215
# Cost:  0.04805472803339733  after Iteration#:  216
# Cost:  0.04744026585979666  after Iteration#:  217
# Cost:  0.046839278339427894  after Iteration#:  218
# Cost:  0.0462512931280704  after Iteration#:  219
# Cost:  0.04567585473566292  after Iteration#:  220
# Cost:  0.04511252415695344  after Iteration#:  221
# Cost:  0.04456087858513989  after Iteration#:  222
# Cost:  0.044020511191607894  after Iteration#:  223
# Cost:  0.04349103095206172  after Iteration#:  224
# Cost:  0.04297206249787451  after Iteration#:  225
# Cost:  0.04246324597148951  after Iteration#:  226
# Cost:  0.04196423686610502  after Iteration#:  227
# Cost:  0.041474705832499015  after Iteration#:  228
# Cost:  0.04099433843940278  after Iteration#:  229
# Cost:  0.04052283487798204  after Iteration#:  230
# Cost:  0.04005990960530351  after Iteration#:  231
# Cost:  0.03960529092588292  after Iteration#:  232
# Cost:  0.039158720514187034  after Iteration#:  233
# Cost:  0.03871995288408553  after Iteration#:  234
# Cost:  0.03828875481363921  after Iteration#:  235
# Cost:  0.037864904735199295  after Iteration#:  236
# Cost:  0.03744819210159186  after Iteration#:  237
# Cost:  0.037038416739313074  after Iteration#:  238
# Cost:  0.03663538819920702  after Iteration#:  239
# Cost:  0.03623892511424978  after Iteration#:  240
# Cost:  0.035848854572873165  after Iteration#:  241
# Cost:  0.03546501151494849  after Iteration#:  242
# Cost:  0.03508723815610042  after Iteration#:  243
# Cost:  0.03471538344465781  after Iteration#:  244
# Cost:  0.03434930255420812  after Iteration#:  245
# Cost:  0.033988856413533344  after Iteration#:  246
# Cost:  0.033633911274662545  after Iteration#:  247
# Cost:  0.03328433831888972  after Iteration#:  248
# Cost:  0.032940013299868676  after Iteration#:  249
# Cost:  0.03260081622234446  after Iteration#:  250
# Cost:  0.032266631054628764  after Iteration#:  251
# Cost:  0.03193734547264466  after Iteration#:  252
# Cost:  0.0316128506331371  after Iteration#:  253
# Cost:  0.03129304097356711  after Iteration#:  254
# Cost:  0.03097781403616211  after Iteration#:  255
# Cost:  0.030667070313620058  after Iteration#:  256
# Cost:  0.030360713114052293  after Iteration#:  257
# Cost:  0.03005864844284498  after Iteration#:  258
# Cost:  0.02976078489927226  after Iteration#:  259
# Cost:  0.029467033585832476  after Iteration#:  260
# Cost:  0.029177308028449676  after Iteration#:  261
# Cost:  0.02889152410585156  after Iteration#:  262
# Cost:  0.028609599986598892  after Iteration#:  263
# Cost:  0.028331456072408306  after Iteration#:  264
# Cost:  0.02805701494656931  after Iteration#:  265
# Cost:  0.027786201326409597  after Iteration#:  266
# Cost:  0.027518942018892947  after Iteration#:  267
# Cost:  0.027255165878583787  after Iteration#:  268
# Cost:  0.02699480376731398  after Iteration#:  269
# Cost:  0.02673778851500419  after Iteration#:  270
# Cost:  0.026484054881195436  after Iteration#:  271
# Cost:  0.026233539516928153  after Iteration#:  272
# Cost:  0.02598618092667223  after Iteration#:  273
# Cost:  0.02574191943011404  after Iteration#:  274
# Cost:  0.025500697123616446  after Iteration#:  275
# Cost:  0.02526245784126826  after Iteration#:  276
# Cost:  0.025027147115439356  after Iteration#:  277
# Cost:  0.024794712136824316  after Iteration#:  278
# Cost:  0.024565101713975378  after Iteration#:  279
# Cost:  0.02433826623234106  after Iteration#:  280
# Cost:  0.024114157612869933  after Iteration#:  281
# Cost:  0.023892729270228875  after Iteration#:  282
# Cost:  0.02367393607071238  after Iteration#:  283
# Cost:  0.023457734289921477  after Iteration#:  284
# Cost:  0.02324408157030098  after Iteration#:  285
# Cost:  0.023032936878621183  after Iteration#:  286
# Cost:  0.022824260463493343  after Iteration#:  287
# Cost:  0.02261801381301341  after Iteration#:  288
# Cost:  0.02241415961261661  after Iteration#:  289
# Cost:  0.02221266170323398  after Iteration#:  290
# Cost:  0.022013485039826138  after Iteration#:  291
# Cost:  0.021816595650375817  after Iteration#:  292
# Cost:  0.021621960595415973  after Iteration#:  293
# Cost:  0.02142954792815074  after Iteration#:  294
# Cost:  0.021239326655241114  after Iteration#:  295
# Cost:  0.021051266698308695  after Iteration#:  296
# Cost:  0.02086533885620962  after Iteration#:  297
# Cost:  0.020681514768125697  after Iteration#:  298
# Cost:  0.0204997668775102  after Iteration#:  299
# Cost:  0.0203200683969313  after Iteration#:  300
# Cost:  0.020142393273838266  after Iteration#:  301
# Cost:  0.01996671615727555  after Iteration#:  302
# Cost:  0.019793012365573306  after Iteration#:  303
# Cost:  0.01962125785502304  after Iteration#:  304
# Cost:  0.01945142918955594  after Iteration#:  305
# Cost:  0.01928350351143497  after Iteration#:  306
# Cost:  0.019117458512959488  after Iteration#:  307
# Cost:  0.01895327240919162  after Iteration#:  308
# Cost:  0.018790923911698225  after Iteration#:  309
# Cost:  0.018630392203307852  after Iteration#:  310
# Cost:  0.01847165691387355  after Iteration#:  311
# Cost:  0.018314698097034243  after Iteration#:  312
# Cost:  0.01815949620796225  after Iteration#:  313
# Cost:  0.018006032082083408  after Iteration#:  314
# Cost:  0.01785428691475685  after Iteration#:  315
# Cost:  0.017704242241895155  after Iteration#:  316
# Cost:  0.01755587992150504  after Iteration#:  317
# Cost:  0.0174091821161349  after Iteration#:  318
# Cost:  0.01726413127620209  after Iteration#:  319
# Cost:  0.017120710124183133  after Iteration#:  320
# Cost:  0.016978901639639905  after Iteration#:  321
# Cost:  0.016838689045063714  after Iteration#:  322
# Cost:  0.01670005579250671  after Iteration#:  323
# Cost:  0.016562985550985652  after Iteration#:  324
# Cost:  0.016427462194621493  after Iteration#:  325
# Cost:  0.016293469791503624  after Iteration#:  326
# Cost:  0.016160992593240567  after Iteration#:  327
# Cost:  0.016030015025179922  after Iteration#:  328
# Cost:  0.015900521677274185  after Iteration#:  329
# Cost:  0.015772497295558643  after Iteration#:  330
# Cost:  0.01564592677422353  after Iteration#:  331
# Cost:  0.015520795148257186  after Iteration#:  332
# Cost:  0.015397087586626933  after Iteration#:  333
# Cost:  0.015274789385985477  after Iteration#:  334
# Cost:  0.015153885964867459  after Iteration#:  335
# Cost:  0.015034362858362939  after Iteration#:  336
# Cost:  0.014916205713236617  after Iteration#:  337
# Cost:  0.0147994002834777  after Iteration#:  338
# Cost:  0.01468393242625255  after Iteration#:  339
# Cost:  0.014569788098241174  after Iteration#:  340
# Cost:  0.01445695335233815  after Iteration#:  341
# Cost:  0.014345414334695474  after Iteration#:  342
# Cost:  0.014235157282087695  after Iteration#:  343
# Cost:  0.014126168519581721  after Iteration#:  344
# Cost:  0.014018434458491782  after Iteration#:  345
# Cost:  0.013911941594600637  after Iteration#:  346
# Cost:  0.013806676506632086  after Iteration#:  347
# Cost:  0.013702625854956189  after Iteration#:  348
# Cost:  0.013599776380510908  after Iteration#:  349
# Cost:  0.013498114903928238  after Iteration#:  350
# Cost:  0.01339762832483989  after Iteration#:  351
# Cost:  0.013298303621365064  after Iteration#:  352
# Cost:  0.013200127849749886  after Iteration#:  353
# Cost:  0.013103088144153858  after Iteration#:  354
# Cost:  0.013007171716571411  after Iteration#:  355
# Cost:  0.012912365856872828  after Iteration#:  356
# Cost:  0.01281865793295334  after Iteration#:  357
# Cost:  0.012726035390985803  after Iteration#:  358
# Cost:  0.0126344857557564  after Iteration#:  359
# Cost:  0.01254399663108459  after Iteration#:  360
# Cost:  0.012454555700306878  after Iteration#:  361
# Cost:  0.012366150726826328  after Iteration#:  362
# Cost:  0.012278769554713347  after Iteration#:  363
# Cost:  0.012192400109348937  after Iteration#:  364
# Cost:  0.012107030398109422  after Iteration#:  365
# Cost:  0.012022648511079287  after Iteration#:  366
# Cost:  0.01193924262178905  after Iteration#:  367
# Cost:  0.011856800987971582  after Iteration#:  368
# Cost:  0.011775311952331525  after Iteration#:  369
# Cost:  0.011694763943322417  after Iteration#:  370
# Cost:  0.011615145475924656  after Iteration#:  371
# Cost:  0.011536445152425504  after Iteration#:  372
# Cost:  0.01145865166319002  after Iteration#:  373
# Cost:  0.011381753787423027  after Iteration#:  374
# Cost:  0.011305740393920212  after Iteration#:  375
# Cost:  0.011230600441800142  after Iteration#:  376
# Cost:  0.011156322981218901  after Iteration#:  377
# Cost:  0.011082897154063066  after Iteration#:  378
# Cost:  0.0110103121946174  after Iteration#:  379
# Cost:  0.010938557430208506  after Iteration#:  380
# Cost:  0.010867622281816532  after Iteration#:  381
# Cost:  0.010797496264662861  after Iteration#:  382
# Cost:  0.010728168988761824  after Iteration#:  383
# Cost:  0.010659630159440997  after Iteration#:  384
# Cost:  0.010591869577830527  after Iteration#:  385
# Cost:  0.010524877141315205  after Iteration#:  386
# Cost:  0.010458642843951812  after Iteration#:  387
# Cost:  0.010393156776851873  after Iteration#:  388
# Cost:  0.010328409128528034  after Iteration#:  389
# Cost:  0.01026439018520233  after Iteration#:  390
# Cost:  0.010201090331079275  after Iteration#:  391
# Cost:  0.01013850004858209  after Iteration#:  392
# Cost:  0.010076609918549263  after Iteration#:  393
# Cost:  0.01001541062039971  after Iteration#:  394
# Cost:  0.009954892932256005  after Iteration#:  395
# Cost:  0.009895047731033814  after Iteration#:  396
# Cost:  0.009835865992495925  after Iteration#:  397
# Cost:  0.009777338791269078  after Iteration#:  398
# Cost:  0.009719457300825332  after Iteration#:  399
# Cost:  0.00966221279343218  after Iteration#:  400
# Cost:  0.009605596640064188  after Iteration#:  401
# Cost:  0.009549600310285167  after Iteration#:  402
# Cost:  0.00949421537209381  after Iteration#:  403
# Cost:  0.00943943349174086  after Iteration#:  404
# Cost:  0.009385246433512674  after Iteration#:  405
# Cost:  0.009331646059484205  after Iteration#:  406
# Cost:  0.009278624329243696  after Iteration#:  407
# Cost:  0.00922617329958656  after Iteration#:  408
# Cost:  0.009174285124181975  after Iteration#:  409
# Cost:  0.009122952053211663  after Iteration#:  410
# Cost:  0.009072166432982339  after Iteration#:  411
# Cost:  0.009021920705511636  after Iteration#:  412
# Cost:  0.008972207408090129  after Iteration#:  413
# Cost:  0.00892301917281875  after Iteration#:  414
# Cost:  0.00887434872612249  after Iteration#:  415
# Cost:  0.008826188888242256  after Iteration#:  416
# Cost:  0.008778532572703442  after Iteration#:  417
# Cost:  0.008731372785767886  after Iteration#:  418
# Cost:  0.008684702625860637  after Iteration#:  419
# Cost:  0.008638515282981285  after Iteration#:  420
# Cost:  0.008592804038094959  after Iteration#:  421
# Cost:  0.008547562262506867  after Iteration#:  422
# Cost:  0.00850278341722008  after Iteration#:  423
# Cost:  0.008458461052276755  after Iteration#:  424
# Cost:  0.008414588806084162  after Iteration#:  425
# Cost:  0.00837116040472698  after Iteration#:  426
# Cost:  0.008328169661265157  after Iteration#:  427
# Cost:  0.008285610475020126  after Iteration#:  428
# Cost:  0.008243476830845848  after Iteration#:  429
# Cost:  0.008201762798392432  after Iteration#:  430
# Cost:  0.008160462531356147  after Iteration#:  431
# Cost:  0.008119570266718654  after Iteration#:  432
# Cost:  0.008079080323979986  after Iteration#:  433
# Cost:  0.008038987104380545  after Iteration#:  434
# Cost:  0.007999285090112896  after Iteration#:  435
# Cost:  0.007959968843530122  after Iteration#:  436
# Cost:  0.007921033006345689  after Iteration#:  437
# Cost:  0.007882472298824987  after Iteration#:  438
# Cost:  0.007844281518973454  after Iteration#:  439
# Cost:  0.007806455541717898  after Iteration#:  440
# Cost:  0.007768989318085499  after Iteration#:  441
# Cost:  0.0077318778743732134  after Iteration#:  442
# Cost:  0.00769511631132286  after Iteration#:  443
# Cost:  0.007658699803281949  after Iteration#:  444
# Cost:  0.0076226235973698075  after Iteration#:  445
# Cost:  0.0075868830126401485  after Iteration#:  446
# Cost:  0.007551473439238699  after Iteration#:  447
# Cost:  0.007516390337563364  after Iteration#:  448
# Cost:  0.00748162923741966  after Iteration#:  449
# Cost:  0.007447185737181254  after Iteration#:  450
# Cost:  0.007413055502944512  after Iteration#:  451
# Cost:  0.007379234267686786  after Iteration#:  452
# Cost:  0.007345717830426199  after Iteration#:  453
# Cost:  0.0073125020553793055  after Iteration#:  454
# Cost:  0.007279582871123439  after Iteration#:  455
# Cost:  0.007246956269760152  after Iteration#:  456
# Cost:  0.007214618306077332  after Iteration#:  457
# Cost:  0.007182565096721117  after Iteration#:  458
# Cost:  0.007150792819363923  after Iteration#:  459
# Cost:  0.007119297711878183  after Iteration#:  460
# Cost:  0.007088076071513318  after Iteration#:  461
# Cost:  0.007057124254077925  after Iteration#:  462
# Cost:  0.007026438673122326  after Iteration#:  463
# Cost:  0.006996015799129051  after Iteration#:  464
# Cost:  0.006965852158705869  after Iteration#:  465
# Cost:  0.0069359443337829434  after Iteration#:  466
# Cost:  0.006906288960817042  after Iteration#:  467
# Cost:  0.0068768827299994385  after Iteration#:  468
# Cost:  0.006847722384467994  after Iteration#:  469
# Cost:  0.006818804719529119  after Iteration#:  470
# Cost:  0.006790126581878656  after Iteration#:  471
# Cost:  0.006761684868836369  after Iteration#:  472
# Cost:  0.00673347652758006  after Iteration#:  473
# Cost:  0.006705498554388841  after Iteration#:  474
# Cost:  0.006677747993894076  after Iteration#:  475
# Cost:  0.006650221938333827  after Iteration#:  476
# Cost:  0.006622917526815908  after Iteration#:  477
# Cost:  0.006595831944586935  after Iteration#:  478
# Cost:  0.006568962422309575  after Iteration#:  479
# Cost:  0.006542306235344275  after Iteration#:  480
# Cost:  0.006515860703041555  after Iteration#:  481
# Cost:  0.006489623188038132  after Iteration#:  482
# Cost:  0.006463591095562712  after Iteration#:  483
# Cost:  0.0064377618727482185  after Iteration#:  484
# Cost:  0.0064121330079518046  after Iteration#:  485
# Cost:  0.00638670203008225  after Iteration#:  486
# Cost:  0.006361466507935048  after Iteration#:  487
# Cost:  0.006336424049533794  after Iteration#:  488
# Cost:  0.006311572301483695  after Iteration#:  489
# Cost:  0.006286908948326923  after Iteration#:  490
# Cost:  0.006262431711909616  after Iteration#:  491
# Cost:  0.006238138350755075  after Iteration#:  492
# Cost:  0.006214026659447603  after Iteration#:  493
# Cost:  0.006190094468018765  after Iteration#:  494
# Cost:  0.006166339641347602  after Iteration#:  495
# Cost:  0.006142760078564848  after Iteration#:  496
# Cost:  0.006119353712465658  after Iteration#:  497
# Cost:  0.006096118508932655  after Iteration#:  498
# Cost:  0.006073052466362373  after Iteration#:  499
# Cost:  0.006050153615105677  after Iteration#:  500
# Cost:  0.006027420016908656  after Iteration#:  501
# Cost:  0.00600484976436901  after Iteration#:  502
# Cost:  0.005982440980394728  after Iteration#:  503
# Cost:  0.005960191817672936  after Iteration#:  504
# Cost:  0.005938100458146694  after Iteration#:  505
# Cost:  0.005916165112498757  after Iteration#:  506
# Cost:  0.005894384019642793  after Iteration#:  507
# Cost:  0.005872755446223957  after Iteration#:  508
# Cost:  0.005851277686125595  after Iteration#:  509
# Cost:  0.0058299490599843734  after Iteration#:  510
# Cost:  0.00580876791471172  after Iteration#:  511
# Cost:  0.005787732623024958  after Iteration#:  512
# Cost:  0.005766841582983824  after Iteration#:  513
# Cost:  0.0057460932175366405  after Iteration#:  514
# Cost:  0.005725485974070486  after Iteration#:  515
# Cost:  0.005705018323971916  after Iteration#:  516
# Cost:  0.005684688762193821  after Iteration#:  517
# Cost:  0.0056644958068289945  after Iteration#:  518
# Cost:  0.005644437998691408  after Iteration#:  519
# Cost:  0.005624513900904902  after Iteration#:  520
# Cost:  0.005604722098495794  after Iteration#:  521
# Cost:  0.005585061197998164  after Iteration#:  522
# Cost:  0.005565529827060814  after Iteration#:  523
# Cost:  0.005546126634063182  after Iteration#:  524
# Cost:  0.005526850287737873  after Iteration#:  525
# Cost:  0.005507699476799329  after Iteration#:  526
# Cost:  0.005488672909579956  after Iteration#:  527
# Cost:  0.005469769313670771  after Iteration#:  528
# Cost:  0.005450987435571782  after Iteration#:  529
# Cost:  0.005432326040344734  after Iteration#:  530
# Cost:  0.005413783911274783  after Iteration#:  531
# Cost:  0.0053953598495380265  after Iteration#:  532
# Cost:  0.005377052673873653  after Iteration#:  533
# Cost:  0.0053588612202641215  after Iteration#:  534
# Cost:  0.005340784341619666  after Iteration#:  535
# Cost:  0.005322820907468627  after Iteration#:  536
# Cost:  0.0053049698036550874  after Iteration#:  537
# Cost:  0.005287229932041278  after Iteration#:  538
# Cost:  0.005269600210214091  after Iteration#:  539
# Cost:  0.005252079571200632  after Iteration#:  540
# Cost:  0.005234666963184139  after Iteration#:  541
# Cost:  0.005217361349231401  after Iteration#:  542
# Cost:  0.005200161707019587  after Iteration#:  543
# Cost:  0.0051830670285726264  after Iteration#:  544
# Cost:  0.005166076319999497  after Iteration#:  545
# Cost:  0.005149188601240472  after Iteration#:  546
# Cost:  0.0051324029058152625  after Iteration#:  547
# Cost:  0.005115718280578759  after Iteration#:  548
# Cost:  0.0050991337854797356  after Iteration#:  549
# Cost:  0.005082648493324663  after Iteration#:  550
# Cost:  0.005066261489547829  after Iteration#:  551
# Cost:  0.005049971871981684  after Iteration#:  552
# Cost:  0.005033778750637257  after Iteration#:  553
# Cost:  0.005017681247484939  after Iteration#:  554
# Cost:  0.005001678496240548  after Iteration#:  555
# Cost:  0.004985769642156719  after Iteration#:  556
# Cost:  0.00496995384181677  after Iteration#:  557
# Cost:  0.0049542302629346936  after Iteration#:  558
# Cost:  0.004938598084156575  after Iteration#:  559
# Cost:  0.00492305649486798  after Iteration#:  560
# Cost:  0.004907604695005594  after Iteration#:  561
# Cost:  0.004892241894869564  after Iteration#:  562
# Cost:  0.004876967314942917  after Iteration#:  563
# Cost:  0.004861780185713941  after Iteration#:  564
# Cost:  0.004846679747500358  after Iteration#:  565
# Cost:  0.004831665250278509  after Iteration#:  566
# Cost:  0.004816735953516409  after Iteration#:  567
# Cost:  0.0048018911260087034  after Iteration#:  568
# Cost:  0.004787130045716306  after Iteration#:  569
# Cost:  0.0047724519996081615  after Iteration#:  570
# Cost:  0.004757856283507177  after Iteration#:  571
# Cost:  0.004743342201938868  after Iteration#:  572
# Cost:  0.004728909067982432  after Iteration#:  573
# Cost:  0.004714556203125931  after Iteration#:  574
# Cost:  0.004700282937124479  after Iteration#:  575
# Cost:  0.004686088607859758  after Iteration#:  576
# Cost:  0.004671972561204116  after Iteration#:  577
# Cost:  0.004657934150885518  after Iteration#:  578
# Cost:  0.0046439727383583915  after Iteration#:  579
# Cost:  0.004630087692673982  after Iteration#:  580
# Cost:  0.004616278390353456  after Iteration#:  581
# Cost:  0.004602544215266226  after Iteration#:  582
# Cost:  0.004588884558508165  after Iteration#:  583
# Cost:  0.004575298818283706  after Iteration#:  584
# Cost:  0.004561786399789523  after Iteration#:  585
# Cost:  0.004548346715100708  after Iteration#:  586
# Cost:  0.004534979183059409  after Iteration#:  587
# Cost:  0.004521683229166335  after Iteration#:  588
# Cost:  0.004508458285473055  after Iteration#:  589
# Cost:  0.004495303790477332  after Iteration#:  590
# Cost:  0.00448221918902123  after Iteration#:  591
# Cost:  0.004469203932189133  after Iteration#:  592
# Cost:  0.004456257477210162  after Iteration#:  593
# Cost:  0.004443379287360985  after Iteration#:  594
# Cost:  0.00443056883187164  after Iteration#:  595
# Cost:  0.004417825585832611  after Iteration#:  596
# Cost:  0.0044051490301036285  after Iteration#:  597
# Cost:  0.004392538651223835  after Iteration#:  598
# Cost:  0.00437999394132593  after Iteration#:  599
# Cost:  0.004367514398049681  after Iteration#:  600
# Cost:  0.004355099524457706  after Iteration#:  601
# Cost:  0.004342748828953592  after Iteration#:  602
# Cost:  0.004330461825201035  after Iteration#:  603
# Cost:  0.00431823803204472  after Iteration#:  604
# Cost:  0.004306076973432698  after Iteration#:  605
# Cost:  0.004293978178340637  after Iteration#:  606
# Cost:  0.004281941180697399  after Iteration#:  607
# Cost:  0.004269965519310819  after Iteration#:  608
# Cost:  0.00425805073779748  after Iteration#:  609
# Cost:  0.004246196384511439  after Iteration#:  610
# Cost:  0.004234402012475884  after Iteration#:  611
# Cost:  0.0042226671793142816  after Iteration#:  612
# Cost:  0.004210991447186391  after Iteration#:  613
# Cost:  0.004199374382720762  after Iteration#:  614
# Cost:  0.00418781555695196  after Iteration#:  615
# Cost:  0.00417631454525876  after Iteration#:  616
# Cost:  0.004164870927300824  after Iteration#:  617
# Cost:  0.004153484286960528  after Iteration#:  618
# Cost:  0.0041421542122822815  after Iteration#:  619
# Cost:  0.0041308802954153545  after Iteration#:  620
# Cost:  0.004119662132556421  after Iteration#:  621
# Cost:  0.004108499323894158  after Iteration#:  622
# Cost:  0.004097391473554022  after Iteration#:  623
# Cost:  0.004086338189545072  after Iteration#:  624
# Cost:  0.0040753390837058555  after Iteration#:  625
# Cost:  0.004064393771654206  after Iteration#:  626
# Cost:  0.0040535018727349  after Iteration#:  627
# Cost:  0.004042663009970951  after Iteration#:  628
# Cost:  0.004031876810013229  after Iteration#:  629
# Cost:  0.004021142903093947  after Iteration#:  630
# Cost:  0.004010460922976177  after Iteration#:  631
# Cost:  0.003999830506912697  after Iteration#:  632
# Cost:  0.003989251295594809  after Iteration#:  633
# Cost:  0.003978722933110111  after Iteration#:  634
# Cost:  0.003968245066899232  after Iteration#:  635
# Cost:  0.003957817347711028  after Iteration#:  636
# Cost:  0.0039474394295616316  after Iteration#:  637
# Cost:  0.003937110969690209  after Iteration#:  638
# Cost:  0.003926831628520154  after Iteration#:  639
# Cost:  0.003916601069618805  after Iteration#:  640
# Cost:  0.003906418959655976  after Iteration#:  641
# Cost:  0.003896284968367585  after Iteration#:  642
# Cost:  0.0038861987685145055  after Iteration#:  643
# Cost:  0.003876160035847634  after Iteration#:  644
# Cost:  0.0038661684490687914  after Iteration#:  645
# Cost:  0.003856223689796484  after Iteration#:  646
# Cost:  0.0038463254425286086  after Iteration#:  647
# Cost:  0.003836473394606368  after Iteration#:  648
# Cost:  0.003826667236183104  after Iteration#:  649
# Cost:  0.0038169066601872774  after Iteration#:  650
# Cost:  0.003807191362290036  after Iteration#:  651
# Cost:  0.003797521040872542  after Iteration#:  652
# Cost:  0.0037878953969937438  after Iteration#:  653
# Cost:  0.0037783141343576297  after Iteration#:  654
# Cost:  0.003768776959283281  after Iteration#:  655
# Cost:  0.0037592835806730465  after Iteration#:  656
# Cost:  0.003749833709982581  after Iteration#:  657
# Cost:  0.0037404270611911053  after Iteration#:  658
# Cost:  0.0037310633507726043  after Iteration#:  659
# Cost:  0.0037217422976656813  after Iteration#:  660
# Cost:  0.0037124636232457346  after Iteration#:  661
# Cost:  0.003703227051298057  after Iteration#:  662
# Cost:  0.0036940323079884853  after Iteration#:  663
# Cost:  0.0036848791218378144  after Iteration#:  664
# Cost:  0.0036757672236937874  after Iteration#:  665
# Cost:  0.0036666963467058156  after Iteration#:  666
# Cost:  0.00365766622629886  after Iteration#:  667
# Cost:  0.0036486766001476894  after Iteration#:  668
# Cost:  0.003639727208152317  after Iteration#:  669
# Cost:  0.0036308177924123846  after Iteration#:  670
# Cost:  0.0036219480972033103  after Iteration#:  671
# Cost:  0.0036131178689531303  after Iteration#:  672
# Cost:  0.0036043268562175896  after Iteration#:  673
# Cost:  0.003595574809656949  after Iteration#:  674
# Cost:  0.0035868614820141237  after Iteration#:  675
# Cost:  0.0035781866280910585  after Iteration#:  676
# Cost:  0.003569550004726721  after Iteration#:  677
# Cost:  0.003560951370775326  after Iteration#:  678
# Cost:  0.0035523904870845982  after Iteration#:  679
# Cost:  0.003543867116474772  after Iteration#:  680
# Cost:  0.0035353810237163403  after Iteration#:  681
# Cost:  0.003526931975511393  after Iteration#:  682
# Cost:  0.003518519740470974  after Iteration#:  683
# Cost:  0.003510144089096741  after Iteration#:  684
# Cost:  0.003501804793760173  after Iteration#:  685
# Cost:  0.0034935016286831507  after Iteration#:  686
# Cost:  0.0034852343699180712  after Iteration#:  687
# Cost:  0.003477002795330428  after Iteration#:  688
# Cost:  0.0034688066845785506  after Iteration#:  689
# Cost:  0.003460645819095041  after Iteration#:  690
# Cost:  0.003452519982069794  after Iteration#:  691
# Cost:  0.00344442895843086  after Iteration#:  692
# Cost:  0.0034363725348267307  after Iteration#:  693
# Cost:  0.0034283504996090912  after Iteration#:  694
# Cost:  0.003420362642815551  after Iteration#:  695
# Cost:  0.0034124087561529202  after Iteration#:  696
# Cost:  0.0034044886329786554  after Iteration#:  697
# Cost:  0.0033966020682866796  after Iteration#:  698
# Cost:  0.0033887488586891957  after Iteration#:  699
# Cost:  0.00338092880240151  after Iteration#:  700
# Cost:  0.003373141699224756  after Iteration#:  701
# Cost:  0.0033653873505314572  after Iteration#:  702
# Cost:  0.003357665559249632  after Iteration#:  703
# Cost:  0.003349976129846737  after Iteration#:  704
# Cost:  0.0033423188683153167  after Iteration#:  705
# Cost:  0.0033346935821574036  after Iteration#:  706
# Cost:  0.0033271000803701614  after Iteration#:  707
# Cost:  0.003319538173430779  after Iteration#:  708
# Cost:  0.0033120076732826844  after Iteration#:  709
# Cost:  0.0033045083933211693  after Iteration#:  710
# Cost:  0.0032970401483782123  after Iteration#:  711
# Cost:  0.003289602754710433  after Iteration#:  712
# Cost:  0.0032821960299842133  after Iteration#:  713
# Cost:  0.003274819793261721  after Iteration#:  714
# Cost:  0.00326747386498888  after Iteration#:  715
# Cost:  0.0032601580669809668  after Iteration#:  716
# Cost:  0.003252872222410153  after Iteration#:  717
# Cost:  0.003245616155792666  after Iteration#:  718
# Cost:  0.003238389692975146  after Iteration#:  719
# Cost:  0.003231192661123309  after Iteration#:  720
# Cost:  0.003224024888708919  after Iteration#:  721
# Cost:  0.0032168862054969306  after Iteration#:  722
# Cost:  0.0032097764425342524  after Iteration#:  723
# Cost:  0.003202695432137404  after Iteration#:  724
# Cost:  0.003195643007880623  after Iteration#:  725
# Cost:  0.0031886190045835056  after Iteration#:  726
# Cost:  0.003181623258301451  after Iteration#:  727
# Cost:  0.0031746556063109244  after Iteration#:  728
# Cost:  0.0031677158871011926  after Iteration#:  729
# Cost:  0.003160803940362205  after Iteration#:  730
# Cost:  0.0031539196069721963  after Iteration#:  731
# Cost:  0.0031470627289883995  after Iteration#:  732
# Cost:  0.003140233149635744  after Iteration#:  733
# Cost:  0.003133430713296095  after Iteration#:  734
# Cost:  0.0031266552654973714  after Iteration#:  735
# Cost:  0.0031199066529035606  after Iteration#:  736
# Cost:  0.0031131847233045215  after Iteration#:  737
# Cost:  0.0031064893256049107  after Iteration#:  738
# Cost:  0.0030998203098146822  after Iteration#:  739
# Cost:  0.0030931775270401298  after Iteration#:  740
# Cost:  0.0030865608294719164  after Iteration#:  741
# Cost:  0.0030799700703765557  after Iteration#:  742
# Cost:  0.0030734051040865497  after Iteration#:  743
# Cost:  0.003066865785991811  after Iteration#:  744
# Cost:  0.0030603519725272725  after Iteration#:  745
# Cost:  0.003053863521167899  after Iteration#:  746
# Cost:  0.0030474002904155614  after Iteration#:  747
# Cost:  0.0030409621397914023  after Iteration#:  748
# Cost:  0.0030345489298279986  after Iteration#:  749
# Cost:  0.003028160522058383  after Iteration#:  750
# Cost:  0.00302179677900805  after Iteration#:  751
# Cost:  0.0030154575641872542  after Iteration#:  752
# Cost:  0.0030091427420795825  after Iteration#:  753
# Cost:  0.00300285217813672  after Iteration#:  754
# Cost:  0.002996585738768042  after Iteration#:  755
# Cost:  0.002990343291332208  after Iteration#:  756
# Cost:  0.0029841247041300523  after Iteration#:  757
# Cost:  0.002977929846394551  after Iteration#:  758
# Cost:  0.0029717585882848064  after Iteration#:  759
# Cost:  0.002965610800876957  after Iteration#:  760
# Cost:  0.002959486356155078  after Iteration#:  761
# Cost:  0.0029533851270063284  after Iteration#:  762
# Cost:  0.0029473069872098688  after Iteration#:  763
# Cost:  0.0029412518114311573  after Iteration#:  764
# Cost:  0.0029352194752140285  after Iteration#:  765
# Cost:  0.0029292098549730467  after Iteration#:  766
# Cost:  0.002923222827985559  after Iteration#:  767
# Cost:  0.002917258272385171  after Iteration#:  768
# Cost:  0.002911316067154012  after Iteration#:  769
# Cost:  0.002905396092114391  after Iteration#:  770
# Cost:  0.002899498227924709  after Iteration#:  771
# Cost:  0.0028936223560685832  after Iteration#:  772
# Cost:  0.0028877683588507184  after Iteration#:  773
# Cost:  0.002881936119388786  after Iteration#:  774
# Cost:  0.0028761255216056608  after Iteration#:  775
# Cost:  0.002870336450225485  after Iteration#:  776
# Cost:  0.002864568790763581  after Iteration#:  777
# Cost:  0.0028588224295218027  after Iteration#:  778
# Cost:  0.0028530972535817435  after Iteration#:  779
# Cost:  0.0028473931507975547  after Iteration#:  780
# Cost:  0.0028417100097897566  after Iteration#:  781
# Cost:  0.0028360477199390745  after Iteration#:  782
# Cost:  0.0028304061713798935  after Iteration#:  783
# Cost:  0.0028247852549943397  after Iteration#:  784
# Cost:  0.0028191848624054276  after Iteration#:  785
# Cost:  0.0028136048859713297  after Iteration#:  786
# Cost:  0.0028080452187792624  after Iteration#:  787
# Cost:  0.002802505754639491  after Iteration#:  788
# Cost:  0.0027969863880790394  after Iteration#:  789
# Cost:  0.0027914870143362367  after Iteration#:  790
# Cost:  0.0027860075293547606  after Iteration#:  791
# Cost:  0.00278054782977726  after Iteration#:  792
# Cost:  0.0027751078129408953  after Iteration#:  793
# Cost:  0.0027696873768701395  after Iteration#:  794
# Cost:  0.00276428642027201  after Iteration#:  795
# Cost:  0.0027589048425306966  after Iteration#:  796
# Cost:  0.0027535425437014084  after Iteration#:  797
# Cost:  0.002748199424505507  after Iteration#:  798
# Cost:  0.0027428753863242977  after Iteration#:  799
# Cost:  0.002737570331194752  after Iteration#:  800
# Cost:  0.002732284161803404  after Iteration#:  801
# Cost:  0.002727016781481119  after Iteration#:  802
# Cost:  0.002721768094198307  after Iteration#:  803
# Cost:  0.0027165380045594155  after Iteration#:  804
# Cost:  0.002711326417798264  after Iteration#:  805
# Cost:  0.002706133239772243  after Iteration#:  806
# Cost:  0.002700958376958128  after Iteration#:  807
# Cost:  0.002695801736446214  after Iteration#:  808
# Cost:  0.002690663225936643  after Iteration#:  809
# Cost:  0.002685542753732985  after Iteration#:  810
# Cost:  0.0026804402287391367  after Iteration#:  811
# Cost:  0.0026753555604529422  after Iteration#:  812
# Cost:  0.002670288658962226  after Iteration#:  813
# Cost:  0.0026652394349407377  after Iteration#:  814
# Cost:  0.0026602077996417768  after Iteration#:  815
# Cost:  0.002655193664895571  after Iteration#:  816
# Cost:  0.0026501969431031603  after Iteration#:  817
# Cost:  0.002645217547232803  after Iteration#:  818
# Cost:  0.0026402553908151604  after Iteration#:  819
# Cost:  0.0026353103879387116  after Iteration#:  820
# Cost:  0.002630382453245919  after Iteration#:  821
# Cost:  0.002625471501928576  after Iteration#:  822
# Cost:  0.0026205774497227293  after Iteration#:  823
# Cost:  0.0026157002129060802  after Iteration#:  824
# Cost:  0.0026108397082920936  after Iteration#:  825
# Cost:  0.002605995853227192  after Iteration#:  826
# Cost:  0.0026011685655848967  after Iteration#:  827
# Cost:  0.0025963577637639623  after Iteration#:  828
# Cost:  0.0025915633666823727  after Iteration#:  829
# Cost:  0.0025867852937740982  after Iteration#:  830
# Cost:  0.002582023464985283  after Iteration#:  831
# Cost:  0.002577277800769633  after Iteration#:  832
# Cost:  0.0025725482220851814  after Iteration#:  833
# Cost:  0.0025678346503900567  after Iteration#:  834
# Cost:  0.002563137007638565  after Iteration#:  835
# Cost:  0.0025584552162776887  after Iteration#:  836
# Cost:  0.0025537891992424835  after Iteration#:  837
# Cost:  0.0025491388799536055  after Iteration#:  838
# Cost:  0.0025445041823126714  after Iteration#:  839
# Cost:  0.0025398850306985934  after Iteration#:  840
# Cost:  0.0025352813499640854  after Iteration#:  841
# Cost:  0.002530693065432534  after Iteration#:  842
# Cost:  0.0025261201028940173  after Iteration#:  843
# Cost:  0.0025215623886009238  after Iteration#:  844
# Cost:  0.0025170198492656835  after Iteration#:  845
# Cost:  0.002512492412057433  after Iteration#:  846
# Cost:  0.002507980004596677  after Iteration#:  847
# Cost:  0.0025034825549538993  after Iteration#:  848
# Cost:  0.002498999991645538  after Iteration#:  849
# Cost:  0.0024945322436296085  after Iteration#:  850
# Cost:  0.002490079240304315  after Iteration#:  851
# Cost:  0.0024856409115027833  after Iteration#:  852
# Cost:  0.002481217187490595  after Iteration#:  853
# Cost:  0.002476807998963317  after Iteration#:  854
# Cost:  0.002472413277042216  after Iteration#:  855
# Cost:  0.0024680329532707555  after Iteration#:  856
# Cost:  0.002463666959613117  after Iteration#:  857
# Cost:  0.0024593152284491412  after Iteration#:  858
# Cost:  0.002454977692572682  after Iteration#:  859
# Cost:  0.0024506542851874067  after Iteration#:  860
# Cost:  0.0024463449399046043  after Iteration#:  861
# Cost:  0.0024420495907399448  after Iteration#:  862
# Cost:  0.002437768172109715  after Iteration#:  863
# Cost:  0.002433500618829118  after Iteration#:  864
# Cost:  0.002429246866108577  after Iteration#:  865
# Cost:  0.002425006849550604  after Iteration#:  866
# Cost:  0.0024207805051476685  after Iteration#:  867
# Cost:  0.002416567769278219  after Iteration#:  868
# Cost:  0.0024123685787049614  after Iteration#:  869
# Cost:  0.0024081828705710753  after Iteration#:  870
# Cost:  0.002404010582399043  after Iteration#:  871
# Cost:  0.00239985165208532  after Iteration#:  872
# Cost:  0.002395706017899511  after Iteration#:  873
# Cost:  0.002391573618481661  after Iteration#:  874
# Cost:  0.0023874543928380054  after Iteration#:  875
# Cost:  0.0023833482803404713  after Iteration#:  876
# Cost:  0.002379255220721405  after Iteration#:  877
# Cost:  0.0023751751540737323  after Iteration#:  878
# Cost:  0.0023711080208462763  after Iteration#:  879
# Cost:  0.0023670537618412165  after Iteration#:  880
# Cost:  0.0023630123182141255  after Iteration#:  881
# Cost:  0.0023589836314675526  after Iteration#:  882
# Cost:  0.002354967643451163  after Iteration#:  883
# Cost:  0.0023509642963586356  after Iteration#:  884
# Cost:  0.0023469735327250087  after Iteration#:  885
# Cost:  0.002342995295423591  after Iteration#:  886
# Cost:  0.002339029527665239  after Iteration#:  887
# Cost:  0.0023350761729942536  after Iteration#:  888
# Cost:  0.0023311351752858603  after Iteration#:  889
# Cost:  0.0023272064787460698  after Iteration#:  890
# Cost:  0.002323290027907261  after Iteration#:  891
# Cost:  0.002319385767626028  after Iteration#:  892
# Cost:  0.0023154936430812446  after Iteration#:  893
# Cost:  0.002311613599771783  after Iteration#:  894
# Cost:  0.0023077455835148475  after Iteration#:  895
# Cost:  0.0023038895404424546  after Iteration#:  896
# Cost:  0.002300045416999717  after Iteration#:  897
# Cost:  0.002296213159942847  after Iteration#:  898
# Cost:  0.0022923927163372676  after Iteration#:  899
# Cost:  0.002288584033554339  after Iteration#:  900
# Cost:  0.002284787059270277  after Iteration#:  901
# Cost:  0.0022810017414627492  after Iteration#:  902
# Cost:  0.0022772280284105205  after Iteration#:  903
# Cost:  0.002273465868689586  after Iteration#:  904
# Cost:  0.002269715211172682  after Iteration#:  905
# Cost:  0.00226597600502554  after Iteration#:  906
# Cost:  0.0022622481997057625  after Iteration#:  907
# Cost:  0.002258531744961327  after Iteration#:  908
# Cost:  0.0022548265908267865  after Iteration#:  909
# Cost:  0.002251132687623564  after Iteration#:  910
# Cost:  0.002247449985955945  after Iteration#:  911
# Cost:  0.002243778436709824  after Iteration#:  912
# Cost:  0.0022401179910516017  after Iteration#:  913
# Cost:  0.0022364686004245453  after Iteration#:  914
# Cost:  0.002232830216548708  after Iteration#:  915
# Cost:  0.0022292027914170903  after Iteration#:  916
# Cost:  0.0022255862772955375  after Iteration#:  917
# Cost:  0.0022219806267193476  after Iteration#:  918
# Cost:  0.0022183857924926225  after Iteration#:  919
# Cost:  0.002214801727685735  after Iteration#:  920
# Cost:  0.002211228385633587  after Iteration#:  921
# Cost:  0.002207665719933829  after Iteration#:  922
# Cost:  0.0022041136844452927  after Iteration#:  923
# Cost:  0.002200572233285448  after Iteration#:  924
# Cost:  0.002197041320829365  after Iteration#:  925
# Cost:  0.0021935209017083183  after Iteration#:  926
# Cost:  0.0021900109308067516  after Iteration#:  927
# Cost:  0.0021865113632611615  after Iteration#:  928
# Cost:  0.0021830221544591375  after Iteration#:  929
# Cost:  0.0021795432600361948  after Iteration#:  930
# Cost:  0.002176074635874966  after Iteration#:  931
# Cost:  0.0021726162381039177  after Iteration#:  932
# Cost:  0.002169168023094947  after Iteration#:  933
# Cost:  0.002165729947461727  after Iteration#:  934
# Cost:  0.0021623019680579274  after Iteration#:  935
# Cost:  0.00215888404197695  after Iteration#:  936
# Cost:  0.002155476126548372  after Iteration#:  937
# Cost:  0.00215207817933778  after Iteration#:  938
# Cost:  0.0021486901581445304  after Iteration#:  939
# Cost:  0.002145312021000046  after Iteration#:  940
# Cost:  0.002141943726166426  after Iteration#:  941
# Cost:  0.0021385852321361607  after Iteration#:  942
# Cost:  0.002135236497628017  after Iteration#:  943
# Cost:  0.0021318974815875  after Iteration#:  944
# Cost:  0.0021285681431843853  after Iteration#:  945
# Cost:  0.0021252484418120606  after Iteration#:  946
# Cost:  0.002121938337085387  after Iteration#:  947
# Cost:  0.0021186377888390423  after Iteration#:  948
# Cost:  0.002115346757127118  after Iteration#:  949
# Cost:  0.002112065202219723  after Iteration#:  950
# Cost:  0.002108793084604053  after Iteration#:  951
# Cost:  0.0021055303649807717  after Iteration#:  952
# Cost:  0.0021022770042639213  after Iteration#:  953
# Cost:  0.0020990329635787413  after Iteration#:  954
# Cost:  0.0020957982042604066  after Iteration#:  955
# Cost:  0.002092572687853443  after Iteration#:  956
# Cost:  0.002089356376109149  after Iteration#:  957
# Cost:  0.0020861492309852386  after Iteration#:  958
# Cost:  0.002082951214643006  after Iteration#:  959
# Cost:  0.0020797622894489806  after Iteration#:  960
# Cost:  0.0020765824179691697  after Iteration#:  961
# Cost:  0.0020734115629724124  after Iteration#:  962
# Cost:  0.0020702496874248247  after Iteration#:  963
# Cost:  0.0020670967544921502  after Iteration#:  964
# Cost:  0.0020639527275356844  after Iteration#:  965
# Cost:  0.002060817570113122  after Iteration#:  966
# Cost:  0.0020576912459749166  after Iteration#:  967
# Cost:  0.002054573719065902  after Iteration#:  968
# Cost:  0.0020514649535209074  after Iteration#:  969
# Cost:  0.002048364913666439  after Iteration#:  970
# Cost:  0.0020452735640173413  after Iteration#:  971
# Cost:  0.0020421908692768013  after Iteration#:  972
# Cost:  0.0020391167943342274  after Iteration#:  973
# Cost:  0.0020360513042646388  after Iteration#:  974
# Cost:  0.0020329943643275427  after Iteration#:  975
# Cost:  0.00202994593996503  after Iteration#:  976
# Cost:  0.002026905996801255  after Iteration#:  977
# Cost:  0.002023874500641339  after Iteration#:  978
# Cost:  0.0020208514174696376  after Iteration#:  979
# Cost:  0.0020178367134488255  after Iteration#:  980
# Cost:  0.0020148303549192637  after Iteration#:  981
# Cost:  0.002011832308396778  after Iteration#:  982
# Cost:  0.0020088425405724204  after Iteration#:  983
# Cost:  0.0020058610183113254  after Iteration#:  984
# Cost:  0.0020028877086507085  after Iteration#:  985
# Cost:  0.0019999225788004727  after Iteration#:  986
# Cost:  0.0019969655961399745  after Iteration#:  987
# Cost:  0.001994016728219066  after Iteration#:  988
# Cost:  0.0019910759427545113  after Iteration#:  989
# Cost:  0.0019881432076317997  after Iteration#:  990
# Cost:  0.0019852184909019957  after Iteration#:  991
# Cost:  0.0019823017607813395  after Iteration#:  992
# Cost:  0.001979392985649978  after Iteration#:  993
# Cost:  0.0019764921340519074  after Iteration#:  994
# Cost:  0.001973599174692523  after Iteration#:  995
# Cost:  0.0019707140764383072  after Iteration#:  996
# Cost:  0.001967836808316451  after Iteration#:  997
# Cost:  0.0019649673395117037  after Iteration#:  998
# Cost:  0.001962105639368451  after Iteration#:  999
# Cost:  0.0019592516773866905  after Iteration#:  1000

# %%
W1.T.shape, W2.shape
# Out:
# ((240, 10), (240, 10))

# %%
((W1.T+ W2)/2).shape
# Out:
# (240, 10)

# %% [markdown]
# ### Visualizing word vectors with t-sne

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
new_values = tsne_model.fit_transform(W2)

x = []
y = []
for value in new_values:
    x.append(value[0])
    y.append(value[1])

plt.figure(figsize=(16, 16)) 
for i in range(len(x)):
    plt.scatter(x[i],y[i])
    plt.annotate(tokens[i],
                 xy=(x[i], y[i]),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
plt.show()
# Out:
# C:\Users\JOY\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\JOY\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
