# %%
import re
import numpy as np
from tqdm import tqdm

# %%
inp_data = "Since the so-called "statistical revolution"[15][16] in the late 1980s and mid-1990s, much natural language processing research has relied heavily on machine learning. The machine-learning paradigm calls instead for using statistical inference to automatically learn such rules through the analysis of large corpora (the plural form of corpus, is a set of documents, possibly with human or computer annotations) of typical real-world examples.
Many different classes of machine-learning algorithms have been applied to natural-language-processing tasks. These algorithms take as input a large set of "features" that are generated from the input data. Increasingly, however, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to each input feature (complex-valued embeddings,[17] and neural networks in general have also been proposed, for e.g. speech[18]). Such models have the advantage that they can express the relative certainty of many different possible answers rather than only one, producing more reliable results when such a model is included as a component of a larger system.
Some of the earliest-used machine learning algorithms, such as decision trees, produced systems of hard if-then rules similar to existing hand-written rules. However, part-of-speech tagging introduced the use of hidden Markov models to natural language processing, and increasingly, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to the features making up the input data. The cache language models upon which many speech recognition systems now rely are examples of such statistical models. Such models are generally more robust when given unfamiliar input, especially input that contains errors (as is very common for real-world data), and produce more reliable results when integrated into a larger system comprising multiple subtasks.
Since the neural turn, statistical methods in NLP research have been largely replaced by neural networks. However, they continue to be relevant for contexts in which statistical interpretability and transparency is required.
Neural networks
Further information: Artificial neural network
A major drawback of statistical methods is that they require elaborate feature engineering. Since 2015,[19] the field has thus largely abandoned statistical methods and shifted to neural networks for machine learning. Popular techniques include the use of word embeddings to capture semantic properties of words, and an increase in end-to-end learning of a higher-level task (e.g., question answering) instead of relying on a pipeline of separate intermediate tasks (e.g., part-of-speech tagging and dependency parsing). In some areas, this shift has entailed substantial changes in how NLP systems are designed, such that deep neural network-based approaches may be viewed as a new paradigm distinct from statistical natural language processing. For instance, the term neural machine translation (NMT) emphasizes the fact that deep learning-based approaches to machine translation directly learn sequence-to-sequence transformations, obviating the need for intermediate steps such as word alignment and language modeling that was used in statistical machine translation (SMT)."

# %%
# remove special characters
inp_data2 = re.sub('[^A-Za-z0-9]+', ' ', inp_data)

# remove 1 letter words
inp_data2 = re.sub(r'(?:^| )\w(?:$| )', ' ', inp_data2).strip()

# lower all characters
inp_data2 = inp_data2.lower()

# %%
inp_data2
# Out:
# 'the speed of transmission is an important point of difference between the two viruses influenza has shorter median incubation period the time from infection to appearance of symptoms and shorter serial interval the time between successive cases than covid 19 virus the serial interval for covid 19 virus is estimated to be 6 days while for influenza virus the serial interval is days this means that influenza can spread faster than covid 19 further transmission in the first 5 days of illness or potentially pre symptomatic transmission transmission of the virus before the appearance of symptoms is major driver of transmission for influenza in contrast while we are learning that there are people who can shed covid 19 virus 24 48 hours prior to symptom onset at present this does not appear to be major driver of transmission the reproductive number the number of secondary infections generated from one infected individual is understood to be between and 5 for covid 19 virus higher than for influenza however estimates for both covid 19 and influenza viruses are very context and time specific making direct comparisons more difficult'

# %%
tokens = inp_data2.split()
vocab = set(tokens)

# %%
word_to_index = {word: i for i, word in enumerate(vocab)}
index_to_word = {i: word for i, word in enumerate(vocab)}

# %%
context_size = 4 #Hyper-parameter
batch_size = 8
embedding_size = 10 #Hyper-parameter
vocab_size = len(vocab) #Number of unique tokens in the vocabulary

# %%
embedding_size, vocab_size
# Out:
# (10, 97)

# %%
data[:5]
# Out:
# [(['speed', 'transmission', 'the', 'is'], 'of'),
#  (['of', 'is', 'speed', 'an'], 'transmission'),
#  (['transmission', 'an', 'of', 'important'], 'is'),
#  (['is', 'important', 'transmission', 'point'], 'an'),
#  (['an', 'point', 'is', 'of'], 'important')]

# %%
data = []

for i in range(context_size, len(tokens) - context_size):
  target = tokens[i]
  context = []
  for j in range(1, context_size+1):
    context += [tokens[i-j], tokens[i+j]]  
  data.append((context, target))

print(data[:5])
# Out:
# [(['speed', 'transmission', 'the', 'is'], 'of'), (['of', 'is', 'speed', 'an'], 'transmission'), (['transmission', 'an', 'of', 'important'], 'is'), (['is', 'important', 'transmission', 'point'], 'an'), (['an', 'point', 'is', 'of'], 'important')]

# %%
len(data)
# Out:
# 182

# %%
# Initialize Weights and Bias matrices
def initialize_weights(vocab_size, embedding_size):
  W1 = np.random.rand(embedding_size, vocab_size)
  W2 = np.random.rand(vocab_size, embedding_size)
  b1 = np.random.rand(embedding_size, 1)
  b2 = np.random.rand(vocab_size, 1)
  return W1, b1, W2, b2

# %%
def softmax_activation(z):
  return np.exp(z)/np.sum(np.exp(z), axis=0)

# %%
# Forward Propagation:
# 1. Linear Hidden State: h = W1.x + b1
# 2. Output Layer:        z = W2.h + b2
# 3. Softmax Activation:  z = softmax_activation(z)

def forward_propagation(X, W1, W2, b1, b2):
  # Compute Hidden Layer values
  h = np.dot(W1, X) + b1
  # Compute Output Layer Values
  z = np.dot(W2, h) + b2
  return z, h

# %%
def transform_data(context_words, target_word, vocab_size):
  input_vector = np.zeros((vocab_size, 1))
  target_vector = np.zeros((vocab_size, 1))
  
  for word in context_words:
    input_vector[word_to_index[word]] += 1
  
  input_vector = input_vector/len(context_words)

  target_vector[word_to_index[target_word]]=1

  return input_vector.reshape(1, -1), target_vector.reshape(1, -1)

# %%
def transform_batch_data(batch_data, vocab_size):
  X=np.zeros((vocab_size, len(batch_data)))
  y=np.zeros((vocab_size, len(batch_data)))

  for i in range(len(batch_data)):
    context_words = batch_data[i][0]
    target_word = batch_data[i][1]

    X[:, i], y[:, i] = transform_data(context_words, target_word, vocab_size)

  return X, y

# %%
def get_batch_indices(data, batch_size):
  batch_indices = []

  for i in range(0, len(data), batch_size):
    if (i+batch_size <= len(data)):
      batch_indices.append((i, i+batch_size))
    else:
      batch_indices.append((i, len(data)))
  return batch_indices

# %%
batch_indices = get_batch_indices(data, batch_size)

batch_indices
# Out:
# [(0, 8),
#  (8, 16),
#  (16, 24),
#  (24, 32),
#  (32, 40),
#  (40, 48),
#  (48, 56),
#  (56, 64),
#  (64, 72),
#  (72, 80),
#  (80, 88),
#  (88, 96),
#  (96, 104),
#  (104, 112),
#  (112, 120),
#  (120, 128),
#  (128, 136),
#  (136, 144),
#  (144, 152),
#  (152, 160),
#  (160, 168),
#  (168, 176),
#  (176, 182)]

# %%
# compute_cost: cross-entropy cost functioN
def compute_cost(y, yhat, batch_size):
    # cost function 
    logprobs = np.multiply(np.log(yhat),y)
    cost = - 1/batch_size * np.sum(logprobs)
    cost = np.squeeze(cost)
    return cost

# %%
def back_propagation(X, y_hat, y, h, W1, W2, b1, b2, batch_size):
    
    l1 = np.dot(W2.T,(y_hat-y))
    
    grad_W1 = (1/batch_size)*np.dot(l1, X.T) 
    
    grad_W2 = (1/batch_size)*np.dot(y_hat-y, h.T)
    
    grad_b1 = np.sum((1/batch_size)*np.dot(l1, X.T), axis=1, keepdims=True)
    
    grad_b2 = np.sum((1/batch_size)*np.dot(y_hat-y,h.T), axis=1, keepdims=True)
    
    return grad_W1, grad_W2, grad_b1, grad_b2

# %%
alpha = 0.3

W1, b1, W2, b2 = initialize_weights(vocab_size, embedding_size)

batch_indices = get_batch_indices(data, batch_size)

for i in range(1000):
  for start_index, end_index in batch_indices:
    X, y = transform_batch_data(data[start_index:end_index], vocab_size)
    z, h = forward_propagation(X, W1, W2, b1, b2)
    y_hat = softmax_activation(z)
    cost = compute_cost(y, y_hat, batch_size)

    grad_W1, grad_W2, grad_b1, grad_b2 = back_propagation(X, y_hat, y, h, W1, W2, b1, b2, batch_size)
          
    # Update weights and biases
    W1 -= alpha*grad_W1 
    W2 -= alpha*grad_W2
    b1 -= alpha*grad_b1
    b2 -= alpha*grad_b2
  print("Cost: ", cost, " after Iteration#: ", i+1)
# Out:
# Cost:  4.860873924003341  after Iteration#:  1
# Cost:  4.639227311257319  after Iteration#:  2
# Cost:  4.519472093866707  after Iteration#:  3
# Cost:  4.444629739184146  after Iteration#:  4
# Cost:  4.3932501319903  after Iteration#:  5
# Cost:  4.3550904165667  after Iteration#:  6
# Cost:  4.324736289432322  after Iteration#:  7
# Cost:  4.2991473722883  after Iteration#:  8
# Cost:  4.276523291297011  after Iteration#:  9
# Cost:  4.2557433382090455  after Iteration#:  10
# Cost:  4.236076826004041  after Iteration#:  11
# Cost:  4.2170273981094475  after Iteration#:  12
# Cost:  4.198246506302962  after Iteration#:  13
# Cost:  4.179484125168107  after Iteration#:  14
# Cost:  4.160560296126622  after Iteration#:  15
# Cost:  4.141348676351108  after Iteration#:  16
# Cost:  4.121767138279637  after Iteration#:  17
# Cost:  4.101772608632421  after Iteration#:  18
# Cost:  4.081358688029921  after Iteration#:  19
# Cost:  4.060555523435427  after Iteration#:  20
# Cost:  4.039431928228413  after Iteration#:  21
# Cost:  4.018099686715838  after Iteration#:  22
# Cost:  3.9967192311434423  after Iteration#:  23
# Cost:  3.9755046664059597  after Iteration#:  24
# Cost:  3.9547251115775666  after Iteration#:  25
# Cost:  3.934699369718163  after Iteration#:  26
# Cost:  3.915782404544956  after Iteration#:  27
# Cost:  3.898344361341752  after Iteration#:  28
# Cost:  3.882744488562513  after Iteration#:  29
# Cost:  3.8693020926323074  after Iteration#:  30
# Cost:  3.8582645189617155  after Iteration#:  31
# Cost:  3.8497690769904596  after Iteration#:  32
# Cost:  3.843793011891419  after Iteration#:  33
# Cost:  3.8400834313410934  after Iteration#:  34
# Cost:  3.838056007694416  after Iteration#:  35
# Cost:  3.836643927128642  after Iteration#:  36
# Cost:  3.8340666645259995  after Iteration#:  37
# Cost:  3.8274926756844705  after Iteration#:  38
# Cost:  3.812673454906941  after Iteration#:  39
# Cost:  3.784001958426298  after Iteration#:  40
# Cost:  3.736110802071316  after Iteration#:  41
# Cost:  3.6677664801517267  after Iteration#:  42
# Cost:  3.5849489700642687  after Iteration#:  43
# Cost:  3.4979985627650407  after Iteration#:  44
# Cost:  3.4156685796520674  after Iteration#:  45
# Cost:  3.342161850189484  after Iteration#:  46
# Cost:  3.2778427939054455  after Iteration#:  47
# Cost:  3.221317830604392  after Iteration#:  48
# Cost:  3.1708649375656988  after Iteration#:  49
# Cost:  3.1249227364270316  after Iteration#:  50
# Cost:  3.0821503483505746  after Iteration#:  51
# Cost:  3.0414107329131745  after Iteration#:  52
# Cost:  3.0017641568313085  after Iteration#:  53
# Cost:  2.962465656079119  after Iteration#:  54
# Cost:  2.92295757328401  after Iteration#:  55
# Cost:  2.8828554075780004  after Iteration#:  56
# Cost:  2.8419266538947294  after Iteration#:  57
# Cost:  2.8000631390121775  after Iteration#:  58
# Cost:  2.75724966906476  after Iteration#:  59
# Cost:  2.71353350965577  after Iteration#:  60
# Cost:  2.668998761278637  after Iteration#:  61
# Cost:  2.6237476749963915  after Iteration#:  62
# Cost:  2.5778888337772567  after Iteration#:  63
# Cost:  2.531530817295288  after Iteration#:  64
# Cost:  2.4847795724141326  after Iteration#:  65
# Cost:  2.4377379023700745  after Iteration#:  66
# Cost:  2.390505906417925  after Iteration#:  67
# Cost:  2.3431816247681883  after Iteration#:  68
# Cost:  2.29586148092711  after Iteration#:  69
# Cost:  2.248640350450917  after Iteration#:  70
# Cost:  2.2016112349815264  after Iteration#:  71
# Cost:  2.154864603124425  after Iteration#:  72
# Cost:  2.1084874961669002  after Iteration#:  73
# Cost:  2.062562506622036  after Iteration#:  74
# Cost:  2.0171667363688845  after Iteration#:  75
# Cost:  1.972370836302356  after Iteration#:  76
# Cost:  1.9282382207824027  after Iteration#:  77
# Cost:  1.8848245335487088  after Iteration#:  78
# Cost:  1.8421774138279605  after Iteration#:  79
# Cost:  1.8003365733240533  after Iteration#:  80
# Cost:  1.7593341529678894  after Iteration#:  81
# Cost:  1.719195291882241  after Iteration#:  82
# Cost:  1.6799388184596054  after Iteration#:  83
# Cost:  1.6415779694574182  after Iteration#:  84
# Cost:  1.6041210571069973  after Iteration#:  85
# Cost:  1.5675720313016728  after Iteration#:  86
# Cost:  1.5319309162471737  after Iteration#:  87
# Cost:  1.4971941307090688  after Iteration#:  88
# Cost:  1.4633547223922196  after Iteration#:  89
# Cost:  1.4304025573695103  after Iteration#:  90
# Cost:  1.398324505251351  after Iteration#:  91
# Cost:  1.3671046525643509  after Iteration#:  92
# Cost:  1.3367245641872225  after Iteration#:  93
# Cost:  1.3071635991647614  after Iteration#:  94
# Cost:  1.2783992754479763  after Iteration#:  95
# Cost:  1.250407669638292  after Iteration#:  96
# Cost:  1.2231638331440091  after Iteration#:  97
# Cost:  1.1966422049967034  after Iteration#:  98
# Cost:  1.1708170031648009  after Iteration#:  99
# Cost:  1.1456625796029574  after Iteration#:  100
# Cost:  1.121153728582786  after Iteration#:  101
# Cost:  1.0972659423145554  after Iteration#:  102
# Cost:  1.0739756119539114  after Iteration#:  103
# Cost:  1.0512601754680793  after Iteration#:  104
# Cost:  1.029098216370456  after Iteration#:  105
# Cost:  1.0074695190163871  after Iteration#:  106
# Cost:  0.9863550870720844  after Iteration#:  107
# Cost:  0.9657371320576313  after Iteration#:  108
# Cost:  0.9455990386750159  after Iteration#:  109
# Cost:  0.9259253131085009  after Iteration#:  110
# Cost:  0.906701519754444  after Iteration#:  111
# Cost:  0.8879142110033791  after Iteration#:  112
# Cost:  0.8695508538366934  after Iteration#:  113
# Cost:  0.8515997561688864  after Iteration#:  114
# Cost:  0.8340499951010341  after Iteration#:  115
# Cost:  0.8168913485743059  after Iteration#:  116
# Cost:  0.8001142313361099  after Iteration#:  117
# Cost:  0.783709635659972  after Iteration#:  118
# Cost:  0.7676690768924719  after Iteration#:  119
# Cost:  0.7519845436311045  after Iteration#:  120
# Cost:  0.7366484521574996  after Iteration#:  121
# Cost:  0.7216536046501943  after Iteration#:  122
# Cost:  0.7069931506675586  after Iteration#:  123
# Cost:  0.6926605514109243  after Iteration#:  124
# Cost:  0.678649546336523  after Iteration#:  125
# Cost:  0.6649541217687522  after Iteration#:  126
# Cost:  0.6515684812642052  after Iteration#:  127
# Cost:  0.6384870175747246  after Iteration#:  128
# Cost:  0.625704286149547  after Iteration#:  129
# Cost:  0.6132149801947556  after Iteration#:  130
# Cost:  0.6010139073682532  after Iteration#:  131
# Cost:  0.5890959682280184  after Iteration#:  132
# Cost:  0.5774561365702942  after Iteration#:  133
# Cost:  0.5660894417937281  after Iteration#:  134
# Cost:  0.5549909534080919  after Iteration#:  135
# Cost:  0.5441557677752837  after Iteration#:  136
# Cost:  0.53357899712995  after Iteration#:  137
# Cost:  0.5232557608811329  after Iteration#:  138
# Cost:  0.5131811791487821  after Iteration#:  139
# Cost:  0.5033503684430651  after Iteration#:  140
# Cost:  0.4937584393530129  after Iteration#:  141
# Cost:  0.4844004960761352  after Iteration#:  142
# Cost:  0.47527163759358737  after Iteration#:  143
# Cost:  0.46636696027684954  after Iteration#:  144
# Cost:  0.4576815617017215  after Iteration#:  145
# Cost:  0.4492105454431612  after Iteration#:  146
# Cost:  0.44094902662929286  after Iteration#:  147
# Cost:  0.4328921380435599  after Iteration#:  148
# Cost:  0.4250350365793263  after Iteration#:  149
# Cost:  0.41737290986988074  after Iteration#:  150
# Cost:  0.40990098293759925  after Iteration#:  151
# Cost:  0.40261452472791953  after Iteration#:  152
# Cost:  0.3955088544157106  after Iteration#:  153
# Cost:  0.3885793473930014  after Iteration#:  154
# Cost:  0.38182144086711445  after Iteration#:  155
# Cost:  0.3752306390167522  after Iteration#:  156
# Cost:  0.36880251767014205  after Iteration#:  157
# Cost:  0.36253272848390494  after Iteration#:  158
# Cost:  0.35641700261377623  after Iteration#:  159
# Cost:  0.3504511538787769  after Iteration#:  160
# Cost:  0.3446310814289831  after Iteration#:  161
# Cost:  0.338952771933854  after Iteration#:  162
# Cost:  0.33341230131328514  after Iteration#:  163
# Cost:  0.32800583603739747  after Iteration#:  164
# Cost:  0.3227296340236973  after Iteration#:  165
# Cost:  0.31758004516183924  after Iteration#:  166
# Cost:  0.3125535114969865  after Iteration#:  167
# Cost:  0.3076465671028247  after Iteration#:  168
# Cost:  0.30285583767478697  after Iteration#:  169
# Cost:  0.29817803987312863  after Iteration#:  170
# Cost:  0.2936099804442625  after Iteration#:  171
# Cost:  0.2891485551472567  after Iteration#:  172
# Cost:  0.2847907475108078  after Iteration#:  173
# Cost:  0.2805336274442505  after Iteration#:  174
# Cost:  0.2763743497244153  after Iteration#:  175
# Cost:  0.27231015237837924  after Iteration#:  176
# Cost:  0.26833835498042014  after Iteration#:  177
# Cost:  0.2644563568798105  after Iteration#:  178
# Cost:  0.26066163537446596  after Iteration#:  179
# Cost:  0.25695174384395925  after Iteration#:  180
# Cost:  0.2533243098539649  after Iteration#:  181
# Cost:  0.2497770332428676  after Iteration#:  182
# Cost:  0.24630768420002663  after Iteration#:  183
# Cost:  0.24291410134405525  after Iteration#:  184
# Cost:  0.23959418980841835  after Iteration#:  185
# Cost:  0.23634591934069882  after Iteration#:  186
# Cost:  0.233167322421017  after Iteration#:  187
# Cost:  0.23005649240430426  after Iteration#:  188
# Cost:  0.22701158169041097  after Iteration#:  189
# Cost:  0.22403079992541514  after Iteration#:  190
# Cost:  0.2211124122369016  after Iteration#:  191
# Cost:  0.21825473750549246  after Iteration#:  192
# Cost:  0.21545614667445706  after Iteration#:  193
# Cost:  0.21271506109880994  after Iteration#:  194
# Cost:  0.210029950934977  after Iteration#:  195
# Cost:  0.2073993335717855  after Iteration#:  196
# Cost:  0.2048217721032553  after Iteration#:  197
# Cost:  0.20229587384344733  after Iteration#:  198
# Cost:  0.19982028888340136  after Iteration#:  199
# Cost:  0.19739370869002948  after Iteration#:  200
# Cost:  0.1950148647466684  after Iteration#:  201
# Cost:  0.19268252723486973  after Iteration#:  202
# Cost:  0.19039550375688685  after Iteration#:  203
# Cost:  0.1881526380982355  after Iteration#:  204
# Cost:  0.18595280902961667  after Iteration#:  205
# Cost:  0.18379492914742868  after Iteration#:  206
# Cost:  0.18167794375204568  after Iteration#:  207
# Cost:  0.17960082976299996  after Iteration#:  208
# Cost:  0.17756259467016727  after Iteration#:  209
# Cost:  0.17556227552003922  after Iteration#:  210
# Cost:  0.17359893793614  after Iteration#:  211
# Cost:  0.17167167517265214  after Iteration#:  212
# Cost:  0.1697796072002871  after Iteration#:  213
# Cost:  0.16792187982346515  after Iteration#:  214
# Cost:  0.16609766382784735  after Iteration#:  215
# Cost:  0.16430615415728655  after Iteration#:  216
# Cost:  0.1625465691192713  after Iteration#:  217
# Cost:  0.16081814961794752  after Iteration#:  218
# Cost:  0.15912015841381813  after Iteration#:  219
# Cost:  0.1574518794092401  after Iteration#:  220
# Cost:  0.15581261695885806  after Iteration#:  221
# Cost:  0.1542016952041262  after Iteration#:  222
# Cost:  0.15261845743109775  after Iteration#:  223
# Cost:  0.15106226545068024  after Iteration#:  224
# Cost:  0.14953249900057325  after Iteration#:  225
# Cost:  0.14802855516813307  after Iteration#:  226
# Cost:  0.1465498478334199  after Iteration#:  227
# Cost:  0.14509580713172154  after Iteration#:  228
# Cost:  0.14366587893485352  after Iteration#:  229
# Cost:  0.14225952435056438  after Iteration#:  230
# Cost:  0.14087621923939875  after Iteration#:  231
# Cost:  0.13951545374838828  after Iteration#:  232
# Cost:  0.13817673186095875  after Iteration#:  233
# Cost:  0.13685957096247148  after Iteration#:  234
# Cost:  0.13556350142082618  after Iteration#:  235
# Cost:  0.13428806618158334  after Iteration#:  236
# Cost:  0.13303282037706818  after Iteration#:  237
# Cost:  0.13179733094895724  after Iteration#:  238
# Cost:  0.13058117628384658  after Iteration#:  239
# Cost:  0.12938394586133362  after Iteration#:  240
# Cost:  0.12820523991414828  after Iteration#:  241
# Cost:  0.12704466909990564  after Iteration#:  242
# Cost:  0.12590185418403965  after Iteration#:  243
# Cost:  0.12477642573352096  after Iteration#:  244
# Cost:  0.12366802382096442  after Iteration#:  245
# Cost:  0.12257629773874022  after Iteration#:  246
# Cost:  0.12150090572272937  after Iteration#:  247
# Cost:  0.1204415146853746  after Iteration#:  248
# Cost:  0.1193977999576819  after Iteration#:  249
# Cost:  0.11836944503985197  after Iteration#:  250
# Cost:  0.11735614136022818  after Iteration#:  251
# Cost:  0.11635758804225686  after Iteration#:  252
# Cost:  0.11537349167917632  after Iteration#:  253
# Cost:  0.11440356611614697  after Iteration#:  254
# Cost:  0.1134475322395614  after Iteration#:  255
# Cost:  0.11250511777327242  after Iteration#:  256
# Cost:  0.11157605708149465  after Iteration#:  257
# Cost:  0.11066009097813195  after Iteration#:  258
# Cost:  0.10975696654231254  after Iteration#:  259
# Cost:  0.10886643693989921  after Iteration#:  260
# Cost:  0.10798826125077404  after Iteration#:  261
# Cost:  0.10712220430167624  after Iteration#:  262
# Cost:  0.10626803650441294  after Iteration#:  263
# Cost:  0.10542553369924537  after Iteration#:  264
# Cost:  0.10459447700326413  after Iteration#:  265
# Cost:  0.10377465266358506  after Iteration#:  266
# Cost:  0.10296585191519561  after Iteration#:  267
# Cost:  0.10216787084328344  after Iteration#:  268
# Cost:  0.10138051024989757  after Iteration#:  269
# Cost:  0.1006035755247876  after Iteration#:  270
# Cost:  0.09983687652027727  after Iteration#:  271
# Cost:  0.0990802274300329  after Iteration#:  272
# Cost:  0.09833344667158832  after Iteration#:  273
# Cost:  0.09759635677250632  after Iteration#:  274
# Cost:  0.09686878426004317  after Iteration#:  275
# Cost:  0.09615055955419578  after Iteration#:  276
# Cost:  0.09544151686402703  after Iteration#:  277
# Cost:  0.09474149408714469  after Iteration#:  278
# Cost:  0.09405033271223637  after Iteration#:  279
# Cost:  0.09336787772454609  after Iteration#:  280
# Cost:  0.09269397751421507  after Iteration#:  281
# Cost:  0.09202848378735973  after Iteration#:  282
# Cost:  0.09137125147982489  after Iteration#:  283
# Cost:  0.09072213867350118  after Iteration#:  284
# Cost:  0.09008100651513434  after Iteration#:  285
# Cost:  0.08944771913753809  after Iteration#:  286
# Cost:  0.08882214358313054  after Iteration#:  287
# Cost:  0.08820414972972164  after Iteration#:  288
# Cost:  0.08759361021847403  after Iteration#:  289
# Cost:  0.08699040038396436  after Iteration#:  290
# Cost:  0.08639439818628658  after Iteration#:  291
# Cost:  0.08580548414511462  after Iteration#:  292
# Cost:  0.08522354127567643  after Iteration#:  293
# Cost:  0.08464845502656732  after Iteration#:  294
# Cost:  0.08408011321934636  after Iteration#:  295
# Cost:  0.08351840598986374  after Iteration#:  296
# Cost:  0.0829632257312507  after Iteration#:  297
# Cost:  0.08241446703853535  after Iteration#:  298
# Cost:  0.08187202665481777  after Iteration#:  299
# Cost:  0.08133580341896567  after Iteration#:  300
# Cost:  0.08080569821477605  after Iteration#:  301
# Cost:  0.08028161392156022  after Iteration#:  302
# Cost:  0.07976345536610399  after Iteration#:  303
# Cost:  0.07925112927596423  after Iteration#:  304
# Cost:  0.07874454423405855  after Iteration#:  305
# Cost:  0.07824361063450305  after Iteration#:  306
# Cost:  0.07774824063966852  after Iteration#:  307
# Cost:  0.07725834813840979  after Iteration#:  308
# Cost:  0.07677384870543444  after Iteration#:  309
# Cost:  0.07629465956177894  after Iteration#:  310
# Cost:  0.07582069953635179  after Iteration#:  311
# Cost:  0.07535188902851919  after Iteration#:  312
# Cost:  0.07488814997169206  after Iteration#:  313
# Cost:  0.0744294057978945  after Iteration#:  314
# Cost:  0.07397558140327715  after Iteration#:  315
# Cost:  0.07352660311454465  after Iteration#:  316
# Cost:  0.07308239865628018  after Iteration#:  317
# Cost:  0.07264289711912963  after Iteration#:  318
# Cost:  0.07220802892882448  after Iteration#:  319
# Cost:  0.07177772581601906  after Iteration#:  320
# Cost:  0.07135192078691646  after Iteration#:  321
# Cost:  0.07093054809465901  after Iteration#:  322
# Cost:  0.07051354321146514  after Iteration#:  323
# Cost:  0.07010084280148327  after Iteration#:  324
# Cost:  0.06969238469434973  after Iteration#:  325
# Cost:  0.06928810785942618  after Iteration#:  326
# Cost:  0.06888795238069437  after Iteration#:  327
# Cost:  0.06849185943229527  after Iteration#:  328
# Cost:  0.0680997712546908  after Iteration#:  329
# Cost:  0.06771163113142614  after Iteration#:  330
# Cost:  0.0673273833664837  after Iteration#:  331
# Cost:  0.06694697326220725  after Iteration#:  332
# Cost:  0.06657034709777608  after Iteration#:  333
# Cost:  0.06619745210822393  after Iteration#:  334
# Cost:  0.06582823646397562  after Iteration#:  335
# Cost:  0.06546264925089586  after Iteration#:  336
# Cost:  0.0651006404508302  after Iteration#:  337
# Cost:  0.0647421609226277  after Iteration#:  338
# Cost:  0.0643871623836296  after Iteration#:  339
# Cost:  0.0640355973916114  after Iteration#:  340
# Cost:  0.06368741932716857  after Iteration#:  341
# Cost:  0.06334258237652712  after Iteration#:  342
# Cost:  0.0630010415147782  after Iteration#:  343
# Cost:  0.06266275248950945  after Iteration#:  344
# Cost:  0.062327671804838614  after Iteration#:  345
# Cost:  0.06199575670582878  after Iteration#:  346
# Cost:  0.06166696516327279  after Iteration#:  347
# Cost:  0.061341255858849836  after Iteration#:  348
# Cost:  0.06101858817062475  after Iteration#:  349
# Cost:  0.06069892215889962  after Iteration#:  350
# Cost:  0.060382218552396186  after Iteration#:  351
# Cost:  0.060068438734763356  after Iteration#:  352
# Cost:  0.05975754473140554  after Iteration#:  353
# Cost:  0.05944949919661318  after Iteration#:  354
# Cost:  0.059144265401000165  after Iteration#:  355
# Cost:  0.058841807219228354  after Iteration#:  356
# Cost:  0.05854208911802035  after Iteration#:  357
# Cost:  0.05824507614444685  after Iteration#:  358
# Cost:  0.05795073391448427  after Iteration#:  359
# Cost:  0.05765902860183859  after Iteration#:  360
# Cost:  0.05736992692701797  after Iteration#:  361
# Cost:  0.05708339614666151  after Iteration#:  362
# Cost:  0.05679940404310879  after Iteration#:  363
# Cost:  0.05651791891420223  after Iteration#:  364
# Cost:  0.05623890956332572  after Iteration#:  365
# Cost:  0.055962345289664726  after Iteration#:  366
# Cost:  0.05568819587868368  after Iteration#:  367
# Cost:  0.05541643159281867  after Iteration#:  368
# Cost:  0.055147023162378725  after Iteration#:  369
# Cost:  0.054879941776647415  after Iteration#:  370
# Cost:  0.054615159075182065  after Iteration#:  371
# Cost:  0.054352647139306674  after Iteration#:  372
# Cost:  0.054092378483792  after Iteration#:  373
# Cost:  0.053834326048717004  after Iteration#:  374
# Cost:  0.05357846319150987  after Iteration#:  375
# Cost:  0.05332476367916328  after Iteration#:  376
# Cost:  0.053073201680617285  after Iteration#:  377
# Cost:  0.05282375175931048  after Iteration#:  378
# Cost:  0.052576388865887974  after Iteration#:  379
# Cost:  0.052331088331071945  after Iteration#:  380
# Cost:  0.05208782585868125  after Iteration#:  381
# Cost:  0.051846577518801715  after Iteration#:  382
# Cost:  0.051607319741104205  after Iteration#:  383
# Cost:  0.05137002930830348  after Iteration#:  384
# Cost:  0.051134683349756446  after Iteration#:  385
# Cost:  0.05090125933519482  after Iteration#:  386
# Cost:  0.05066973506859228  after Iteration#:  387
# Cost:  0.0504400886821596  after Iteration#:  388
# Cost:  0.050212298630465085  after Iteration#:  389
# Cost:  0.04998634368468092  after Iteration#:  390
# Cost:  0.04976220292694332  after Iteration#:  391
# Cost:  0.04953985574483975  after Iteration#:  392
# Cost:  0.04931928182600083  after Iteration#:  393
# Cost:  0.04910046115280936  after Iteration#:  394
# Cost:  0.04888337399721797  after Iteration#:  395
# Cost:  0.04866800091567106  after Iteration#:  396
# Cost:  0.04845432274413482  after Iteration#:  397
# Cost:  0.04824232059322363  after Iteration#:  398
# Cost:  0.048031975843429844  after Iteration#:  399
# Cost:  0.047823270140451  after Iteration#:  400
# Cost:  0.0476161853906054  after Iteration#:  401
# Cost:  0.04741070375634891  after Iteration#:  402
# Cost:  0.04720680765187679  after Iteration#:  403
# Cost:  0.04700447973881382  after Iteration#:  404
# Cost:  0.04680370292199257  after Iteration#:  405
# Cost:  0.04660446034531608  after Iteration#:  406
# Cost:  0.04640673538770114  after Iteration#:  407
# Cost:  0.046210511659103434  after Iteration#:  408
# Cost:  0.04601577299662184  after Iteration#:  409
# Cost:  0.04582250346067627  after Iteration#:  410
# Cost:  0.04563068733126666  after Iteration#:  411
# Cost:  0.04544030910429999  after Iteration#:  412
# Cost:  0.04525135348799137  after Iteration#:  413
# Cost:  0.04506380539933657  after Iteration#:  414
# Cost:  0.044877649960648996  after Iteration#:  415
# Cost:  0.04469287249617036  after Iteration#:  416
# Cost:  0.0445094585287409  after Iteration#:  417
# Cost:  0.04432739377653692  after Iteration#:  418
# Cost:  0.04414666414986994  after Iteration#:  419
# Cost:  0.04396725574804909  after Iteration#:  420
# Cost:  0.04378915485630115  after Iteration#:  421
# Cost:  0.043612347942751456  after Iteration#:  422
# Cost:  0.04343682165545877  after Iteration#:  423
# Cost:  0.04326256281951367  after Iteration#:  424
# Cost:  0.04308955843418184  after Iteration#:  425
# Cost:  0.04291779567011007  after Iteration#:  426
# Cost:  0.042747261866579886  after Iteration#:  427
# Cost:  0.04257794452881554  after Iteration#:  428
# Cost:  0.04240983132533872  after Iteration#:  429
# Cost:  0.04224291008537709  after Iteration#:  430
# Cost:  0.042077168796318246  after Iteration#:  431
# Cost:  0.04191259560121126  after Iteration#:  432
# Cost:  0.0417491787963153  after Iteration#:  433
# Cost:  0.041586906828692635  after Iteration#:  434
# Cost:  0.04142576829384742  after Iteration#:  435
# Cost:  0.04126575193340655  after Iteration#:  436
# Cost:  0.04110684663284157  after Iteration#:  437
# Cost:  0.040949041419236366  after Iteration#:  438
# Cost:  0.040792325459092595  after Iteration#:  439
# Cost:  0.04063668805617321  after Iteration#:  440
# Cost:  0.04048211864939118  after Iteration#:  441
# Cost:  0.04032860681072953  after Iteration#:  442
# Cost:  0.04017614224320229  after Iteration#:  443
# Cost:  0.040024714778854456  after Iteration#:  444
# Cost:  0.0398743143767903  after Iteration#:  445
# Cost:  0.03972493112124716  after Iteration#:  446
# Cost:  0.03957655521969241  after Iteration#:  447
# Cost:  0.03942917700096549  after Iteration#:  448
# Cost:  0.039282786913444036  after Iteration#:  449
# Cost:  0.039137375523247  after Iteration#:  450
# Cost:  0.038992933512467305  after Iteration#:  451
# Cost:  0.03884945167743905  after Iteration#:  452
# Cost:  0.03870692092703065  after Iteration#:  453
# Cost:  0.03856533228097025  after Iteration#:  454
# Cost:  0.038424676868201266  after Iteration#:  455
# Cost:  0.03828494592526441  after Iteration#:  456
# Cost:  0.03814613079470917  after Iteration#:  457
# Cost:  0.03800822292353388  after Iteration#:  458
# Cost:  0.03787121386164812  after Iteration#:  459
# Cost:  0.037735095260368945  after Iteration#:  460
# Cost:  0.037599858870935435  after Iteration#:  461
# Cost:  0.037465496543056295  after Iteration#:  462
# Cost:  0.03733200022347384  after Iteration#:  463
# Cost:  0.03719936195455929  after Iteration#:  464
# Cost:  0.03706757387293164  after Iteration#:  465
# Cost:  0.036936628208094235  after Iteration#:  466
# Cost:  0.03680651728110039  after Iteration#:  467
# Cost:  0.036677233503238225  after Iteration#:  468
# Cost:  0.03654876937474137  after Iteration#:  469
# Cost:  0.03642111748351591  after Iteration#:  470
# Cost:  0.03629427050389391  after Iteration#:  471
# Cost:  0.036168221195402764  after Iteration#:  472
# Cost:  0.03604296240156124  after Iteration#:  473
# Cost:  0.03591848704869016  after Iteration#:  474
# Cost:  0.035794788144745404  after Iteration#:  475
# Cost:  0.03567185877816846  after Iteration#:  476
# Cost:  0.035549692116759984  after Iteration#:  477
# Cost:  0.035428281406566606  after Iteration#:  478
# Cost:  0.0353076199707898  after Iteration#:  479
# Cost:  0.03518770120871133  after Iteration#:  480
# Cost:  0.035068518594635736  after Iteration#:  481
# Cost:  0.03495006567685224  after Iteration#:  482
# Cost:  0.034832336076611126  after Iteration#:  483
# Cost:  0.0347153234871175  after Iteration#:  484
# Cost:  0.03459902167254146  after Iteration#:  485
# Cost:  0.034483424467046955  after Iteration#:  486
# Cost:  0.03436852577382957  after Iteration#:  487
# Cost:  0.034254319564177224  after Iteration#:  488
# Cost:  0.03414079987654127  after Iteration#:  489
# Cost:  0.034027960815625216  after Iteration#:  490
# Cost:  0.03391579655148403  after Iteration#:  491
# Cost:  0.03380430131864462  after Iteration#:  492
# Cost:  0.03369346941523235  after Iteration#:  493
# Cost:  0.03358329520211652  after Iteration#:  494
# Cost:  0.03347377310206914  after Iteration#:  495
# Cost:  0.033364897598934774  after Iteration#:  496
# Cost:  0.03325666323681497  after Iteration#:  497
# Cost:  0.03314906461926488  after Iteration#:  498
# Cost:  0.033042096408503134  after Iteration#:  499
# Cost:  0.0329357533246344  after Iteration#:  500
# Cost:  0.03283003014488099  after Iteration#:  501
# Cost:  0.032724921702831145  after Iteration#:  502
# Cost:  0.03262042288769596  after Iteration#:  503
# Cost:  0.032516528643579096  after Iteration#:  504
# Cost:  0.03241323396875556  after Iteration#:  505
# Cost:  0.03231053391496368  after Iteration#:  506
# Cost:  0.03220842358671053  after Iteration#:  507
# Cost:  0.03210689814058011  after Iteration#:  508
# Cost:  0.03200595278456161  after Iteration#:  509
# Cost:  0.03190558277737998  after Iteration#:  510
# Cost:  0.031805783427842974  after Iteration#:  511
# Cost:  0.03170655009419271  after Iteration#:  512
# Cost:  0.03160787818347118  after Iteration#:  513
# Cost:  0.03150976315089425  after Iteration#:  514
# Cost:  0.031412200499233364  after Iteration#:  515
# Cost:  0.031315185778207924  after Iteration#:  516
# Cost:  0.031218714583888627  after Iteration#:  517
# Cost:  0.031122782558105383  after Iteration#:  518
# Cost:  0.03102738538786892  after Iteration#:  519
# Cost:  0.030932518804797873  after Iteration#:  520
# Cost:  0.030838178584554152  after Iteration#:  521
# Cost:  0.030744360546290074  after Iteration#:  522
# Cost:  0.030651060552099582  after Iteration#:  523
# Cost:  0.03055827450648043  after Iteration#:  524
# Cost:  0.03046599835580373  after Iteration#:  525
# Cost:  0.030374228087789265  after Iteration#:  526
# Cost:  0.03028295973099203  after Iteration#:  527
# Cost:  0.0301921893542943  after Iteration#:  528
# Cost:  0.03010191306640368  after Iteration#:  529
# Cost:  0.030012127015362752  after Iteration#:  530
# Cost:  0.02992282738806045  after Iteration#:  531
# Cost:  0.029834010409755387  after Iteration#:  532
# Cost:  0.029745672343603848  after Iteration#:  533
# Cost:  0.02965780949019372  after Iteration#:  534
# Cost:  0.029570418187087513  after Iteration#:  535
# Cost:  0.029483494808368975  after Iteration#:  536
# Cost:  0.029397035764201572  after Iteration#:  537
# Cost:  0.029311037500385183  after Iteration#:  538
# Cost:  0.029225496497926984  after Iteration#:  539
# Cost:  0.029140409272613948  after Iteration#:  540
# Cost:  0.02905577237459277  after Iteration#:  541
# Cost:  0.028971582387955816  after Iteration#:  542
# Cost:  0.02888783593033227  after Iteration#:  543
# Cost:  0.02880452965248711  after Iteration#:  544
# Cost:  0.028721660237921855  after Iteration#:  545
# Cost:  0.02863922440248647  after Iteration#:  546
# Cost:  0.028557218893990363  after Iteration#:  547
# Cost:  0.028475640491824314  after Iteration#:  548
# Cost:  0.028394486006585555  after Iteration#:  549
# Cost:  0.028313752279705492  after Iteration#:  550
# Cost:  0.028233436183089246  after Iteration#:  551
# Cost:  0.028153534618752474  after Iteration#:  552
# Cost:  0.02807404451846896  after Iteration#:  553
# Cost:  0.027994962843420207  after Iteration#:  554
# Cost:  0.027916286583850793  after Iteration#:  555
# Cost:  0.027838012758729727  after Iteration#:  556
# Cost:  0.027760138415413416  after Iteration#:  557
# Cost:  0.027682660629315146  after Iteration#:  558
# Cost:  0.027605576503580385  after Iteration#:  559
# Cost:  0.027528883168763722  after Iteration#:  560
# Cost:  0.027452577782512637  after Iteration#:  561
# Cost:  0.027376657529254417  after Iteration#:  562
# Cost:  0.027301119619886113  after Iteration#:  563
# Cost:  0.027225961291472832  after Iteration#:  564
# Cost:  0.027151179806944505  after Iteration#:  565
# Cost:  0.02707677245480159  after Iteration#:  566
# Cost:  0.027002736548821748  after Iteration#:  567
# Cost:  0.026929069427772415  after Iteration#:  568
# Cost:  0.026855768455125557  after Iteration#:  569
# Cost:  0.02678283101877779  after Iteration#:  570
# Cost:  0.026710254530772106  after Iteration#:  571
# Cost:  0.026638036427027334  after Iteration#:  572
# Cost:  0.026566174167065557  after Iteration#:  573
# Cost:  0.026494665233748833  after Iteration#:  574
# Cost:  0.0264235071330145  after Iteration#:  575
# Cost:  0.026352697393618014  after Iteration#:  576
# Cost:  0.02628223356687691  after Iteration#:  577
# Cost:  0.026212113226418372  after Iteration#:  578
# Cost:  0.026142333967931232  after Iteration#:  579
# Cost:  0.026072893408918697  after Iteration#:  580
# Cost:  0.02600378918845833  after Iteration#:  581
# Cost:  0.02593501896696209  after Iteration#:  582
# Cost:  0.025866580425939343  after Iteration#:  583
# Cost:  0.025798471267764984  after Iteration#:  584
# Cost:  0.025730689215450218  after Iteration#:  585
# Cost:  0.025663232012412905  after Iteration#:  586
# Cost:  0.02559609742225773  after Iteration#:  587
# Cost:  0.02552928322855097  after Iteration#:  588
# Cost:  0.025462787234605856  after Iteration#:  589
# Cost:  0.025396607263264946  after Iteration#:  590
# Cost:  0.025330741156687174  after Iteration#:  591
# Cost:  0.025265186776141105  after Iteration#:  592
# Cost:  0.025199942001794186  after Iteration#:  593
# Cost:  0.02513500473251063  after Iteration#:  594
# Cost:  0.025070372885646938  after Iteration#:  595
# Cost:  0.0250060443968564  after Iteration#:  596
# Cost:  0.024942017219888736  after Iteration#:  597
# Cost:  0.024878289326397365  after Iteration#:  598
# Cost:  0.02481485870574687  after Iteration#:  599
# Cost:  0.024751723364824722  after Iteration#:  600
# Cost:  0.024688881327853948  after Iteration#:  601
# Cost:  0.024626330636207405  after Iteration#:  602
# Cost:  0.02456406934822577  after Iteration#:  603
# Cost:  0.024502095539038662  after Iteration#:  604
# Cost:  0.024440407300386026  after Iteration#:  605
# Cost:  0.024379002740441826  after Iteration#:  606
# Cost:  0.02431787998364178  after Iteration#:  607
# Cost:  0.02425703717051226  after Iteration#:  608
# Cost:  0.024196472457499098  after Iteration#:  609
# Cost:  0.0241361840168047  after Iteration#:  610
# Cost:  0.02407617003621759  after Iteration#:  611
# Cost:  0.024016428718954985  after Iteration#:  612
# Cost:  0.023956958283498034  after Iteration#:  613
# Cost:  0.023897756963434734  after Iteration#:  614
# Cost:  0.023838823007302605  after Iteration#:  615
# Cost:  0.023780154678433058  after Iteration#:  616
# Cost:  0.02372175025479975  after Iteration#:  617
# Cost:  0.023663608028865905  after Iteration#:  618
# Cost:  0.02360572630743467  after Iteration#:  619
# Cost:  0.02354810341150431  after Iteration#:  620
# Cost:  0.023490737676118364  after Iteration#:  621
# Cost:  0.02343362745022458  after Iteration#:  622
# Cost:  0.02337677109653081  after Iteration#:  623
# Cost:  0.023320166991366416  after Iteration#:  624
# Cost:  0.023263813524541835  after Iteration#:  625
# Cost:  0.023207709099212444  after Iteration#:  626
# Cost:  0.023151852131740314  after Iteration#:  627
# Cost:  0.02309624105156511  after Iteration#:  628
# Cost:  0.02304087430106761  after Iteration#:  629
# Cost:  0.02298575033544048  after Iteration#:  630
# Cost:  0.022930867622559702  after Iteration#:  631
# Cost:  0.022876224642855027  after Iteration#:  632
# Cost:  0.022821819889187238  after Iteration#:  633
# Cost:  0.022767651866718606  after Iteration#:  634
# Cost:  0.02271371909279512  after Iteration#:  635
# Cost:  0.02266002009682079  after Iteration#:  636
# Cost:  0.022606553420139164  after Iteration#:  637
# Cost:  0.022553317615914142  after Iteration#:  638
# Cost:  0.02250031124901278  after Iteration#:  639
# Cost:  0.022447532895889192  after Iteration#:  640
# Cost:  0.022394981144468758  after Iteration#:  641
# Cost:  0.02234265459403643  after Iteration#:  642
# Cost:  0.02229055185512435  after Iteration#:  643
# Cost:  0.02223867154939891  after Iteration#:  644
# Cost:  0.02218701230955561  after Iteration#:  645
# Cost:  0.02213557277920656  after Iteration#:  646
# Cost:  0.022084351612776297  after Iteration#:  647
# Cost:  0.022033347475394656  after Iteration#:  648
# Cost:  0.02198255904279283  after Iteration#:  649
# Cost:  0.021931985001201446  after Iteration#:  650
# Cost:  0.021881624047245318  after Iteration#:  651
# Cost:  0.021831474887845936  after Iteration#:  652
# Cost:  0.021781536240119338  after Iteration#:  653
# Cost:  0.021731806831278934  after Iteration#:  654
# Cost:  0.02168228539853751  after Iteration#:  655
# Cost:  0.02163297068901053  after Iteration#:  656
# Cost:  0.02158386145962157  after Iteration#:  657
# Cost:  0.021534956477007608  after Iteration#:  658
# Cost:  0.02148625451742668  after Iteration#:  659
# Cost:  0.021437754366664293  after Iteration#:  660
# Cost:  0.02138945481994435  after Iteration#:  661
# Cost:  0.02134135468183821  after Iteration#:  662
# Cost:  0.02129345276617468  after Iteration#:  663
# Cost:  0.021245747895954084  after Iteration#:  664
# Cost:  0.021198238903260197  after Iteration#:  665
# Cost:  0.021150924629174468  after Iteration#:  666
# Cost:  0.021103803923690198  after Iteration#:  667
# Cost:  0.02105687564562947  after Iteration#:  668
# Cost:  0.021010138662560428  after Iteration#:  669
# Cost:  0.020963591850712615  after Iteration#:  670
# Cost:  0.0209172340948994  after Iteration#:  671
# Cost:  0.020871064288433286  after Iteration#:  672
# Cost:  0.020825081333049958  after Iteration#:  673
# Cost:  0.020779284138828437  after Iteration#:  674
# Cost:  0.020733671624112292  after Iteration#:  675
# Cost:  0.020688242715434547  after Iteration#:  676
# Cost:  0.02064299634743938  after Iteration#:  677
# Cost:  0.020597931462809027  after Iteration#:  678
# Cost:  0.020553047012188925  after Iteration#:  679
# Cost:  0.020508341954113073  after Iteration#:  680
# Cost:  0.020463815254931312  after Iteration#:  681
# Cost:  0.020419465888739573  after Iteration#:  682
# Cost:  0.020375292837304382  after Iteration#:  683
# Cost:  0.02033129508999846  after Iteration#:  684
# Cost:  0.0202874716437245  after Iteration#:  685
# Cost:  0.020243821502851318  after Iteration#:  686
# Cost:  0.020200343679142897  after Iteration#:  687
# Cost:  0.020157037191692036  after Iteration#:  688
# Cost:  0.020113901066853294  after Iteration#:  689
# Cost:  0.020070934338177273  after Iteration#:  690
# Cost:  0.020028136046345006  after Iteration#:  691
# Cost:  0.019985505239103814  after Iteration#:  692
# Cost:  0.019943040971202607  after Iteration#:  693
# Cost:  0.019900742304330168  after Iteration#:  694
# Cost:  0.01985860830705083  after Iteration#:  695
# Cost:  0.019816638054743867  after Iteration#:  696
# Cost:  0.01977483062954192  after Iteration#:  697
# Cost:  0.019733185120269905  after Iteration#:  698
# Cost:  0.01969170062238599  after Iteration#:  699
# Cost:  0.019650376237922883  after Iteration#:  700
# Cost:  0.019609211075426243  after Iteration#:  701
# Cost:  0.01956820424989993  after Iteration#:  702
# Cost:  0.019527354882747792  after Iteration#:  703
# Cost:  0.01948666210171491  after Iteration#:  704
# Cost:  0.019446125040833713  after Iteration#:  705
# Cost:  0.01940574284036791  after Iteration#:  706
# Cost:  0.01936551464675543  after Iteration#:  707
# Cost:  0.01932543961255726  after Iteration#:  708
# Cost:  0.019285516896400436  after Iteration#:  709
# Cost:  0.01924574566292738  after Iteration#:  710
# Cost:  0.019206125082740815  after Iteration#:  711
# Cost:  0.01916665433235222  after Iteration#:  712
# Cost:  0.019127332594131533  after Iteration#:  713
# Cost:  0.01908815905625421  after Iteration#:  714
# Cost:  0.019049132912650996  after Iteration#:  715
# Cost:  0.019010253362958758  after Iteration#:  716
# Cost:  0.018971519612469994  after Iteration#:  717
# Cost:  0.018932930872083392  after Iteration#:  718
# Cost:  0.018894486358256454  after Iteration#:  719
# Cost:  0.018856185292957253  after Iteration#:  720
# Cost:  0.018818026903614532  after Iteration#:  721
# Cost:  0.01878001042307454  after Iteration#:  722
# Cost:  0.018742135089550575  after Iteration#:  723
# Cost:  0.01870440014658023  after Iteration#:  724
# Cost:  0.018666804842977017  after Iteration#:  725
# Cost:  0.018629348432785922  after Iteration#:  726
# Cost:  0.018592030175239766  after Iteration#:  727
# Cost:  0.018554849334713117  after Iteration#:  728
# Cost:  0.01851780518068056  after Iteration#:  729
# Cost:  0.018480896987671237  after Iteration#:  730
# Cost:  0.018444124035226273  after Iteration#:  731
# Cost:  0.018407485607858178  after Iteration#:  732
# Cost:  0.018370980995006263  after Iteration#:  733
# Cost:  0.01833460949099552  after Iteration#:  734
# Cost:  0.018298370394997203  after Iteration#:  735
# Cost:  0.01826226301098475  after Iteration#:  736
# Cost:  0.018226286647696217  after Iteration#:  737
# Cost:  0.01819044061859316  after Iteration#:  738
# Cost:  0.01815472424182027  after Iteration#:  739
# Cost:  0.01811913684016688  after Iteration#:  740
# Cost:  0.01808367774102869  after Iteration#:  741
# Cost:  0.018048346276367994  after Iteration#:  742
# Cost:  0.018013141782676205  after Iteration#:  743
# Cost:  0.017978063600935852  after Iteration#:  744
# Cost:  0.01794311107658409  after Iteration#:  745
# Cost:  0.01790828355947486  after Iteration#:  746
# Cost:  0.017873580403841655  after Iteration#:  747
# Cost:  0.01783900096826348  after Iteration#:  748
# Cost:  0.017804544615626673  after Iteration#:  749
# Cost:  0.017770210713090675  after Iteration#:  750
# Cost:  0.017735998632051095  after Iteration#:  751
# Cost:  0.017701907748108633  after Iteration#:  752
# Cost:  0.017667937441029083  after Iteration#:  753
# Cost:  0.01763408709471457  after Iteration#:  754
# Cost:  0.01760035609716564  after Iteration#:  755
# Cost:  0.01756674384044963  after Iteration#:  756
# Cost:  0.017533249720667735  after Iteration#:  757
# Cost:  0.017499873137921212  after Iteration#:  758
# Cost:  0.017466613496278927  after Iteration#:  759
# Cost:  0.01743347020374527  after Iteration#:  760
# Cost:  0.017400442672228518  after Iteration#:  761
# Cost:  0.017367530317508553  after Iteration#:  762
# Cost:  0.01733473255920702  after Iteration#:  763
# Cost:  0.01730204882075288  after Iteration#:  764
# Cost:  0.017269478529356997  after Iteration#:  765
# Cost:  0.017237021115975727  after Iteration#:  766
# Cost:  0.017204676015285778  after Iteration#:  767
# Cost:  0.017172442665651516  after Iteration#:  768
# Cost:  0.01714032050909579  after Iteration#:  769
# Cost:  0.0171083089912715  after Iteration#:  770
# Cost:  0.01707640756143236  after Iteration#:  771
# Cost:  0.017044615672403153  after Iteration#:  772
# Cost:  0.01701293278055187  after Iteration#:  773
# Cost:  0.01698135834576231  after Iteration#:  774
# Cost:  0.01694989183140535  after Iteration#:  775
# Cost:  0.01691853270431047  after Iteration#:  776
# Cost:  0.016887280434740387  after Iteration#:  777
# Cost:  0.016856134496361894  after Iteration#:  778
# Cost:  0.016825094366220046  after Iteration#:  779
# Cost:  0.016794159524711184  after Iteration#:  780
# Cost:  0.016763329455556784  after Iteration#:  781
# Cost:  0.016732603645776473  after Iteration#:  782
# Cost:  0.016701981585663356  after Iteration#:  783
# Cost:  0.016671462768758062  after Iteration#:  784
# Cost:  0.01664104669182201  after Iteration#:  785
# Cost:  0.01661073285481427  after Iteration#:  786
# Cost:  0.01658052076086403  after Iteration#:  787
# Cost:  0.0165504099162491  after Iteration#:  788
# Cost:  0.01652039983036802  after Iteration#:  789
# Cost:  0.016490490015718208  after Iteration#:  790
# Cost:  0.016460679987871422  after Iteration#:  791
# Cost:  0.016430969265449232  after Iteration#:  792
# Cost:  0.01640135737009954  after Iteration#:  793
# Cost:  0.01637184382647406  after Iteration#:  794
# Cost:  0.01634242816220363  after Iteration#:  795
# Cost:  0.016313109907876766  after Iteration#:  796
# Cost:  0.01628388859701569  after Iteration#:  797
# Cost:  0.016254763766055502  after Iteration#:  798
# Cost:  0.016225734954319164  after Iteration#:  799
# Cost:  0.016196801703997534  after Iteration#:  800
# Cost:  0.016167963560126765  after Iteration#:  801
# Cost:  0.016139220070566694  after Iteration#:  802
# Cost:  0.01611057078597846  after Iteration#:  803
# Cost:  0.016082015259804083  after Iteration#:  804
# Cost:  0.0160535530482459  after Iteration#:  805
# Cost:  0.016025183710243803  after Iteration#:  806
# Cost:  0.01599690680745465  after Iteration#:  807
# Cost:  0.015968721904234463  after Iteration#:  808
# Cost:  0.015940628567613822  after Iteration#:  809
# Cost:  0.01591262636728144  after Iteration#:  810
# Cost:  0.01588471487556185  after Iteration#:  811
# Cost:  0.015856893667394963  after Iteration#:  812
# Cost:  0.015829162320319265  after Iteration#:  813
# Cost:  0.01580152041444987  after Iteration#:  814
# Cost:  0.01577396753246022  after Iteration#:  815
# Cost:  0.01574650325956123  after Iteration#:  816
# Cost:  0.015719127183485934  after Iteration#:  817
# Cost:  0.015691838894466886  after Iteration#:  818
# Cost:  0.01566463798521852  after Iteration#:  819
# Cost:  0.015637524050920754  after Iteration#:  820
# Cost:  0.015610496689197128  after Iteration#:  821
# Cost:  0.01558355550010022  after Iteration#:  822
# Cost:  0.015556700086091134  after Iteration#:  823
# Cost:  0.0155299300520219  after Iteration#:  824
# Cost:  0.015503245005119282  after Iteration#:  825
# Cost:  0.015476644554966149  after Iteration#:  826
# Cost:  0.015450128313484102  after Iteration#:  827
# Cost:  0.01542369589491561  after Iteration#:  828
# Cost:  0.015397346915808654  after Iteration#:  829
# Cost:  0.015371080994997828  after Iteration#:  830
# Cost:  0.015344897753589663  after Iteration#:  831
# Cost:  0.015318796814944136  after Iteration#:  832
# Cost:  0.015292777804658715  after Iteration#:  833
# Cost:  0.015266840350552945  after Iteration#:  834
# Cost:  0.015240984082650384  after Iteration#:  835
# Cost:  0.015215208633164327  after Iteration#:  836
# Cost:  0.015189513636481026  after Iteration#:  837
# Cost:  0.015163898729143598  after Iteration#:  838
# Cost:  0.015138363549837408  after Iteration#:  839
# Cost:  0.015112907739373668  after Iteration#:  840
# Cost:  0.01508753094067428  after Iteration#:  841
# Cost:  0.01506223279875577  after Iteration#:  842
# Cost:  0.015037012960716547  after Iteration#:  843
# Cost:  0.015011871075718835  after Iteration#:  844
# Cost:  0.01498680679497608  after Iteration#:  845
# Cost:  0.014961819771737415  after Iteration#:  846
# Cost:  0.014936909661272018  after Iteration#:  847
# Cost:  0.014912076120857626  after Iteration#:  848
# Cost:  0.014887318809762278  after Iteration#:  849
# Cost:  0.014862637389232328  after Iteration#:  850
# Cost:  0.014838031522479499  after Iteration#:  851
# Cost:  0.014813500874662752  after Iteration#:  852
# Cost:  0.01478904511287855  after Iteration#:  853
# Cost:  0.014764663906145952  after Iteration#:  854
# Cost:  0.014740356925391107  after Iteration#:  855
# Cost:  0.014716123843435562  after Iteration#:  856
# Cost:  0.014691964334982974  after Iteration#:  857
# Cost:  0.014667878076604956  after Iteration#:  858
# Cost:  0.01464386474672759  after Iteration#:  859
# Cost:  0.014619924025619277  after Iteration#:  860
# Cost:  0.014596055595377081  after Iteration#:  861
# Cost:  0.014572259139914369  after Iteration#:  862
# Cost:  0.01454853434494715  after Iteration#:  863
# Cost:  0.014524880897983579  after Iteration#:  864
# Cost:  0.014501298488307609  after Iteration#:  865
# Cost:  0.014477786806971045  after Iteration#:  866
# Cost:  0.01445434554677671  after Iteration#:  867
# Cost:  0.014430974402270704  after Iteration#:  868
# Cost:  0.014407673069726372  after Iteration#:  869
# Cost:  0.014384441247134132  after Iteration#:  870
# Cost:  0.014361278634189484  after Iteration#:  871
# Cost:  0.01433818493228169  after Iteration#:  872
# Cost:  0.014315159844479734  after Iteration#:  873
# Cost:  0.014292203075522963  after Iteration#:  874
# Cost:  0.01426931433180957  after Iteration#:  875
# Cost:  0.014246493321383133  after Iteration#:  876
# Cost:  0.014223739753922764  after Iteration#:  877
# Cost:  0.014201053340732711  after Iteration#:  878
# Cost:  0.014178433794727413  after Iteration#:  879
# Cost:  0.014155880830425883  after Iteration#:  880
# Cost:  0.014133394163936093  after Iteration#:  881
# Cost:  0.014110973512945924  after Iteration#:  882
# Cost:  0.014088618596712591  after Iteration#:  883
# Cost:  0.014066329136051756  after Iteration#:  884
# Cost:  0.01404410485332621  after Iteration#:  885
# Cost:  0.014021945472436195  after Iteration#:  886
# Cost:  0.013999850718806932  after Iteration#:  887
# Cost:  0.013977820319382495  after Iteration#:  888
# Cost:  0.01395585400261041  after Iteration#:  889
# Cost:  0.013933951498434958  after Iteration#:  890
# Cost:  0.013912112538285799  after Iteration#:  891
# Cost:  0.013890336855067515  after Iteration#:  892
# Cost:  0.013868624183150666  after Iteration#:  893
# Cost:  0.013846974258360817  after Iteration#:  894
# Cost:  0.013825386817970221  after Iteration#:  895
# Cost:  0.013803861600686229  after Iteration#:  896
# Cost:  0.013782398346641984  after Iteration#:  897
# Cost:  0.013760996797388798  after Iteration#:  898
# Cost:  0.01373965669588446  after Iteration#:  899
# Cost:  0.013718377786484293  after Iteration#:  900
# Cost:  0.013697159814932545  after Iteration#:  901
# Cost:  0.013676002528352174  after Iteration#:  902
# Cost:  0.013654905675235831  after Iteration#:  903
# Cost:  0.013633869005438093  after Iteration#:  904
# Cost:  0.013612892270164179  after Iteration#:  905
# Cost:  0.013591975221962184  after Iteration#:  906
# Cost:  0.013571117614714606  after Iteration#:  907
# Cost:  0.013550319203628484  after Iteration#:  908
# Cost:  0.013529579745226231  after Iteration#:  909
# Cost:  0.013508898997339303  after Iteration#:  910
# Cost:  0.01348827671909683  after Iteration#:  911
# Cost:  0.013467712670918418  after Iteration#:  912
# Cost:  0.013447206614505838  after Iteration#:  913
# Cost:  0.01342675831283336  after Iteration#:  914
# Cost:  0.013406367530140809  after Iteration#:  915
# Cost:  0.01338603403192401  after Iteration#:  916
# Cost:  0.01336575758492755  after Iteration#:  917
# Cost:  0.01334553795713617  after Iteration#:  918
# Cost:  0.013325374917766624  after Iteration#:  919
# Cost:  0.013305268237259187  after Iteration#:  920
# Cost:  0.013285217687270777  after Iteration#:  921
# Cost:  0.013265223040665904  after Iteration#:  922
# Cost:  0.013245284071508991  after Iteration#:  923
# Cost:  0.013225400555057519  after Iteration#:  924
# Cost:  0.013205572267753752  after Iteration#:  925
# Cost:  0.013185798987215799  after Iteration#:  926
# Cost:  0.013166080492231997  after Iteration#:  927
# Cost:  0.0131464165627515  after Iteration#:  928
# Cost:  0.01312680697987933  after Iteration#:  929
# Cost:  0.013107251525864927  after Iteration#:  930
# Cost:  0.013087749984099048  after Iteration#:  931
# Cost:  0.01306830213910349  after Iteration#:  932
# Cost:  0.013048907776525558  after Iteration#:  933
# Cost:  0.013029566683128413  after Iteration#:  934
# Cost:  0.013010278646787672  after Iteration#:  935
# Cost:  0.01299104345648042  after Iteration#:  936
# Cost:  0.012971860902280795  after Iteration#:  937
# Cost:  0.012952730775351813  after Iteration#:  938
# Cost:  0.012933652867938536  after Iteration#:  939
# Cost:  0.01291462697336127  after Iteration#:  940
# Cost:  0.012895652886008795  after Iteration#:  941
# Cost:  0.012876730401331565  after Iteration#:  942
# Cost:  0.012857859315834764  after Iteration#:  943
# Cost:  0.01283903942707152  after Iteration#:  944
# Cost:  0.012820270533637032  after Iteration#:  945
# Cost:  0.012801552435160523  after Iteration#:  946
# Cost:  0.012782884932300075  after Iteration#:  947
# Cost:  0.012764267826736097  after Iteration#:  948
# Cost:  0.0127457009211636  after Iteration#:  949
# Cost:  0.012727184019285978  after Iteration#:  950
# Cost:  0.012708716925811006  after Iteration#:  951
# Cost:  0.012690299446441879  after Iteration#:  952
# Cost:  0.012671931387871194  after Iteration#:  953
# Cost:  0.012653612557776063  after Iteration#:  954
# Cost:  0.012635342764811305  after Iteration#:  955
# Cost:  0.012617121818603194  after Iteration#:  956
# Cost:  0.012598949529743032  after Iteration#:  957
# Cost:  0.012580825709782688  after Iteration#:  958
# Cost:  0.012562750171225786  after Iteration#:  959
# Cost:  0.012544722727525237  after Iteration#:  960
# Cost:  0.012526743193074457  after Iteration#:  961
# Cost:  0.012508811383202211  after Iteration#:  962
# Cost:  0.012490927114168725  after Iteration#:  963
# Cost:  0.012473090203156957  after Iteration#:  964
# Cost:  0.012455300468269294  after Iteration#:  965
# Cost:  0.012437557728519951  after Iteration#:  966
# Cost:  0.012419861803830794  after Iteration#:  967
# Cost:  0.012402212515025154  after Iteration#:  968
# Cost:  0.012384609683823029  after Iteration#:  969
# Cost:  0.012367053132832945  after Iteration#:  970
# Cost:  0.012349542685550182  after Iteration#:  971
# Cost:  0.012332078166348702  after Iteration#:  972
# Cost:  0.01231465940047695  after Iteration#:  973
# Cost:  0.012297286214051588  after Iteration#:  974
# Cost:  0.012279958434053329  after Iteration#:  975
# Cost:  0.012262675888320359  after Iteration#:  976
# Cost:  0.012245438405544842  after Iteration#:  977
# Cost:  0.012228245815264807  after Iteration#:  978
# Cost:  0.012211097947862893  after Iteration#:  979
# Cost:  0.012193994634557719  after Iteration#:  980
# Cost:  0.012176935707400555  after Iteration#:  981
# Cost:  0.012159920999270463  after Iteration#:  982
# Cost:  0.012142950343867772  after Iteration#:  983
# Cost:  0.012126023575710805  after Iteration#:  984
# Cost:  0.01210914053012982  after Iteration#:  985
# Cost:  0.01209230104326204  after Iteration#:  986
# Cost:  0.012075504952048396  after Iteration#:  987
# Cost:  0.01205875209422604  after Iteration#:  988
# Cost:  0.01204204230832625  after Iteration#:  989
# Cost:  0.012025375433667447  after Iteration#:  990
# Cost:  0.012008751310351482  after Iteration#:  991
# Cost:  0.01199216977925957  after Iteration#:  992
# Cost:  0.011975630682045633  after Iteration#:  993
# Cost:  0.011959133861134386  after Iteration#:  994
# Cost:  0.011942679159713886  after Iteration#:  995
# Cost:  0.011926266421733316  after Iteration#:  996
# Cost:  0.011909895491896926  after Iteration#:  997
# Cost:  0.0118935662156598  after Iteration#:  998
# Cost:  0.011877278439224422  after Iteration#:  999
# Cost:  0.011861032009534568  after Iteration#:  1000

# %%
W1.T.shape, W2.shape
# Out:
# ((97, 10), (97, 10))

# %%
((W1.T+ W2)/2).shape
# Out:
# (97, 10)
